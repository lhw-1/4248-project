# %%
##
import sys
# !{sys.executable} -m pip install sentence_transformers
# Out:
# Collecting sentence_transformers
#   Using cached sentence_transformers-2.2.2-py3-none-any.whl
# Requirement already satisfied: scipy in c:\users\ktjam\.conda\envs\nlp202303\lib\site-packages (from sentence_transformers) (1.10.1)
# Requirement already satisfied: numpy in c:\users\ktjam\.conda\envs\nlp202303\lib\site-packages (from sentence_transformers) (1.23.5)
# Requirement already satisfied: nltk in c:\users\ktjam\.conda\envs\nlp202303\lib\site-packages (from sentence_transformers) (3.8.1)
# Requirement already satisfied: huggingface-hub>=0.4.0 in c:\users\ktjam\.conda\envs\nlp202303\lib\site-packages (from sentence_transformers) (0.11.1)
# Requirement already satisfied: tqdm in c:\users\ktjam\.conda\envs\nlp202303\lib\site-packages (from sentence_transformers) (4.64.1)
# Requirement already satisfied: torchvision in c:\users\ktjam\.conda\envs\nlp202303\lib\site-packages (from sentence_transformers) (0.14.0+cu117)
# Requirement already satisfied: torch>=1.6.0 in c:\users\ktjam\.conda\envs\nlp202303\lib\site-packages (from sentence_transformers) (1.13.0+cu117)
# Collecting sentencepiece
#   Using cached sentencepiece-0.1.97-cp39-cp39-win_amd64.whl (1.1 MB)
# Requirement already satisfied: scikit-learn in c:\users\ktjam\.conda\envs\nlp202303\lib\site-packages (from sentence_transformers) (1.2.1)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in c:\users\ktjam\.conda\envs\nlp202303\lib\site-packages (from sentence_transformers) (4.23.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\ktjam\.conda\envs\nlp202303\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (6.0)
# Requirement already satisfied: requests in c:\users\ktjam\.conda\envs\nlp202303\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2.28.1)
# Requirement already satisfied: filelock in c:\users\ktjam\.conda\envs\nlp202303\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (3.8.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\ktjam\.conda\envs\nlp202303\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (4.4.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\ktjam\.conda\envs\nlp202303\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\ktjam\.conda\envs\nlp202303\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\ktjam\.conda\envs\nlp202303\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.13.2)
# Requirement already satisfied: colorama in c:\users\ktjam\.conda\envs\nlp202303\lib\site-packages (from tqdm->sentence_transformers) (0.4.6)
# Requirement already satisfied: joblib in c:\users\ktjam\.conda\envs\nlp202303\lib\site-packages (from nltk->sentence_transformers) (1.2.0)
# Requirement already satisfied: click in c:\users\ktjam\.conda\envs\nlp202303\lib\site-packages (from nltk->sentence_transformers) (8.1.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ktjam\.conda\envs\nlp202303\lib\site-packages (from scikit-learn->sentence_transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\ktjam\.conda\envs\nlp202303\lib\site-packages (from torchvision->sentence_transformers) (9.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\ktjam\.conda\envs\nlp202303\lib\site-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence_transformers) (3.0.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ktjam\.conda\envs\nlp202303\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ktjam\.conda\envs\nlp202303\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ktjam\.conda\envs\nlp202303\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ktjam\.conda\envs\nlp202303\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (1.26.13)
# Installing collected packages: sentencepiece, sentence_transformers
# Successfully installed sentence_transformers-2.2.2 sentencepiece-0.1.97
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ktjam\.conda\envs\nlp202303\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ktjam\.conda\envs\nlp202303\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ktjam\.conda\envs\nlp202303\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ktjam\.conda\envs\nlp202303\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ktjam\.conda\envs\nlp202303\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ktjam\.conda\envs\nlp202303\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ktjam\.conda\envs\nlp202303\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ktjam\.conda\envs\nlp202303\lib\site-packages)

# %%
##
from sentence_transformers import SentenceTransformer
model_st = SentenceTransformer('all-mpnet-base-v2')

# %%
# import stuff
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import inspect
import os
from random import randint
import time

import argparse
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch import optim
from torch.autograd import Variable
import re
from nltk.tokenize import word_tokenize

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# Keep it on CPU or put it on GPU
use_cuda = torch.cuda.is_available()
#or force not to use cuda
#use_cuda = False
model = model.cuda() if use_cuda else model

# %%
class NLINet(nn.Module):
    def __init__(self, config):
        super(NLINet, self).__init__()

        # classifier
        self.nonlinear_fc = config['nonlinear_fc']
        self.fc_dim = config['fc_dim']
        self.n_classes = config['n_classes']
        self.enc_lstm_dim = config['enc_lstm_dim']
        self.encoder_type = config['encoder_type']
        self.dpout_fc = config['dpout_fc']

        self.encoder = model_st  #eval(self.encoder_type)(config)
        self.inputdim = 4*self.enc_lstm_dim  ##4*2*self.enc_lstm_dim
        self.inputdim = self.inputdim if self.encoder_type in \
                        ["ConvNetEncoder", "InnerAttentionMILAEncoder"] else self.inputdim
        self.inputdim = self.inputdim/2 if self.encoder_type == "LSTMEncoder" \
                                        else self.inputdim
        if self.nonlinear_fc:
            self.classifier = nn.Sequential(
                nn.Dropout(p=self.dpout_fc),
                nn.Linear(self.inputdim, self.fc_dim),
                nn.Tanh(),
                nn.Dropout(p=self.dpout_fc),
                nn.Linear(self.fc_dim, self.fc_dim),
                nn.Tanh(),
                nn.Dropout(p=self.dpout_fc),
                nn.Linear(self.fc_dim, self.n_classes),
                )
        else:
            self.classifier = nn.Sequential(
                nn.Linear(self.inputdim, self.fc_dim),
                nn.Linear(self.fc_dim, self.fc_dim),
                nn.Linear(self.fc_dim, self.n_classes)
                )
        #print(nn.Linear(self.inputdim, self.fc_dim).weight.dtype)

    def forward(self, u, v):
        # s1 : (s1, s1_len)
        #u = torch.tensor(self.encoder.encode(s1)).cuda()
        #v = torch.tensor(self.encoder.encode(s2)).cuda()
        #print(u)

        ##s1 and s2 become u and v

        features = torch.cat((u, v, torch.abs(u-v), u*v), 1)
        output = self.classifier(features)
        return output

    def encode(self, s1):
        emb = self.encoder(s1)
        return emb

# %%
##
tmp1 = pd.read_csv('../dataset/esnli_train_1.csv', usecols=['gold_label', 'Sentence1', 'Sentence2'])
tmp2 = pd.read_csv('../dataset/esnli_train_2.csv', usecols=['gold_label', 'Sentence1', 'Sentence2'])
train = pd.concat([tmp1, tmp2], ignore_index=True)
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 549367 entries, 0 to 549366
# Data columns (total 3 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   gold_label  549367 non-null  object
#  1   Sentence1   549367 non-null  object
#  2   Sentence2   549361 non-null  object
# dtypes: object(3)
# memory usage: 12.6+ MB

# %%
##
valid = pd.read_csv('../dataset/esnli_dev.csv', usecols=['gold_label', 'Sentence1', 'Sentence2'])
valid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9842 entries, 0 to 9841
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   gold_label  9842 non-null   object
#  1   Sentence1   9842 non-null   object
#  2   Sentence2   9842 non-null   object
# dtypes: object(3)
# memory usage: 230.8+ KB

# %%
##
test = pd.read_csv('../dataset/esnli_test.csv', usecols=['gold_label', 'Sentence1', 'Sentence2'])
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9824 entries, 0 to 9823
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   gold_label  9824 non-null   object
#  1   Sentence1   9824 non-null   object
#  2   Sentence2   9824 non-null   object
# dtypes: object(3)
# memory usage: 230.4+ KB

# %%
#map label to int
label_to_int = {'entailment': 0, 'neutral': 1, 'contradiction': 2}

# %%
##
#add label int
train['label'] = train['gold_label'].apply(lambda x: label_to_int[x])
valid['label'] = valid['gold_label'].apply(lambda x: label_to_int[x])
test['label'] = test['gold_label'].apply(lambda x: label_to_int[x])

# %%
parser = argparse.ArgumentParser(description='NLI training')
# paths
parser.add_argument("--nlipath", type=str, default='dataset/SNLI/', help="NLI data path (SNLI or MultiNLI)")
parser.add_argument("--outputdir", type=str, default='../savedir/', help="Output directory")
parser.add_argument("--outputmodelname", type=str, default='model.pickle')
parser.add_argument("--word_emb_path", type=str, default="../dataset/GloVe/glove.840B.300d.txt", help="word embedding file path")

# training
parser.add_argument("--n_epochs", type=int, default=40)
parser.add_argument("--batch_size", type=int, default=128)  #64)
parser.add_argument("--dpout_model", type=float, default=0., help="encoder dropout")
parser.add_argument("--dpout_fc", type=float, default=0., help="classifier dropout")
parser.add_argument("--nonlinear_fc", type=float, default=1, help="use nonlinearity in fc")
parser.add_argument("--optimizer", type=str, default="adam,lr=0.001", help="adam or sgd,lr=0.1")
parser.add_argument("--lrshrink", type=float, default=5, help="shrink factor for sgd")
parser.add_argument("--decay", type=float, default=0.99, help="lr decay")
parser.add_argument("--minlr", type=float, default=1e-5, help="minimum lr")
parser.add_argument("--max_norm", type=float, default=5., help="max norm (grad clipping)")

# model
parser.add_argument("--encoder_type", type=str, default='InferSentV1', help="see list of encoders")
parser.add_argument("--enc_lstm_dim", type=int, default=768, help="encoder nhid dimension")  ##2048, help="encoder nhid dimension")
parser.add_argument("--n_enc_layers", type=int, default=1, help="encoder num layers")
parser.add_argument("--fc_dim", type=int, default=512, help="nhid of fc layers")
parser.add_argument("--n_classes", type=int, default=3, help="entailment/neutral/contradiction")
parser.add_argument("--pool_type", type=str, default='max', help="max or mean")

# gpu
parser.add_argument("--gpu_id", type=int, default=3, help="GPU ID")
parser.add_argument("--seed", type=int, default=1234, help="seed")

# data
parser.add_argument("--word_emb_dim", type=int, default=300, help="word embedding dimension")

params, _ = parser.parse_known_args()
config_nli_model = {
    'n_words'        :  1                     ,  ##len(word_vec)          ,
    'word_emb_dim'   :  params.word_emb_dim   ,
    'enc_lstm_dim'   :  params.enc_lstm_dim   ,
    'n_enc_layers'   :  params.n_enc_layers   ,
    'dpout_model'    :  params.dpout_model    ,
    'dpout_fc'       :  params.dpout_fc       ,
    'fc_dim'         :  params.fc_dim         ,
    'bsize'          :  params.batch_size     ,
    'n_classes'      :  params.n_classes      ,
    'pool_type'      :  params.pool_type      ,
    'nonlinear_fc'   :  params.nonlinear_fc   ,
    'encoder_type'   :  params.encoder_type   ,
    'use_cuda'       :  True                  ,

}
nli_net = NLINet(config_nli_model)
print(nli_net)
# Out:
# NLINet(
#   (encoder): SentenceTransformer(
#     (0): Transformer({'max_seq_length': 384, 'do_lower_case': False}) with Transformer model: MPNetModel
#     (1): Pooling({'word_embedding_dimension': 768, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False})
#     (2): Normalize()
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.0, inplace=False)
#     (1): Linear(in_features=3072, out_features=512, bias=True)
#     (2): Tanh()
#     (3): Dropout(p=0.0, inplace=False)
#     (4): Linear(in_features=512, out_features=512, bias=True)
#     (5): Tanh()
#     (6): Dropout(p=0.0, inplace=False)
#     (7): Linear(in_features=512, out_features=3, bias=True)
#   )
# )

# %%
"""
SEED
"""
np.random.seed(params.seed)
torch.manual_seed(params.seed)
torch.cuda.manual_seed(params.seed)

# %%
def get_optimizer(s):
    """
    Parse optimizer parameters.
    Input should be of the form:
        - "sgd,lr=0.01"
        - "adagrad,lr=0.1,lr_decay=0.05"
    """
    if "," in s:
        method = s[:s.find(',')]
        optim_params = {}
        for x in s[s.find(',') + 1:].split(','):
            split = x.split('=')
            assert len(split) == 2
            assert re.match("^[+-]?(\d+(\.\d*)?|\.\d+)$", split[1]) is not None
            optim_params[split[0]] = float(split[1])
    else:
        method = s
        optim_params = {}

    if method == 'adadelta':
        optim_fn = optim.Adadelta
    elif method == 'adagrad':
        optim_fn = optim.Adagrad
    elif method == 'adam':
        optim_fn = optim.Adam
    elif method == 'adamax':
        optim_fn = optim.Adamax
    elif method == 'asgd':
        optim_fn = optim.ASGD
    elif method == 'rmsprop':
        optim_fn = optim.RMSprop
    elif method == 'rprop':
        optim_fn = optim.Rprop
    elif method == 'sgd':
        optim_fn = optim.SGD
        assert 'lr' in optim_params
    else:
        raise Exception('Unknown optimization method: "%s"' % method)

    # check that we give good parameters to the optimizer
    #expected_args = inspect.getargspec(optim_fn.__init__)[0]
    #assert expected_args[:2] == ['self', 'params']
    #if not all(k in expected_args[2:] for k in optim_params.keys()):
    #    raise Exception('Unexpected parameters: expected "%s", got "%s"' % (
    #        str(expected_args[2:]), str(optim_params.keys())))

    return optim_fn, optim_params

# %%
# loss
weight = torch.FloatTensor(params.n_classes).fill_(1)
loss_fn = nn.CrossEntropyLoss(weight=weight)
loss_fn.size_average = False

# optimizer
optim_fn, optim_params = get_optimizer(params.optimizer)
optimizer = optim_fn(nli_net.parameters(), **optim_params)

# cuda by default
nli_net.cuda()
loss_fn.cuda()
# Out:
# CrossEntropyLoss()

# %%
"""
TRAIN
"""
val_acc_best = -1e10
adam_stop = False
stop_training = False
lr = optim_params['lr'] if 'sgd' in params.optimizer else None

# %%
def get_batch(batch):  ##, word_vec, emb_dim=300):
    # sent in batch in decreasing order of lengths (bsize, max_len, word_dim)
    #lengths = np.array([len(x) for x in batch])
    #max_len = np.max(lengths)
    #embed = np.zeros((max_len, len(batch), emb_dim))
    #embed = np.zeros((768, len(batch)), dtype=np.float32)
    ##embed = np.zeros((len(batch), 768), dtype=np.float32)

    ##for i in range(len(batch)):
    ##    #for j in range(len(batch[i])):
    ##        #embed[j, i, :] = batch[i][j]  ##word_vec[batch[i][j]]
    ##    #print(batch)
    ##    emb = nli_net.encoder.encode(str(batch[i]))
    ##    for j in range(768):
    ##      embed[i, j] = emb[j]
          #print(emb[j].dtype)
    #print(embed.dtype)
    #return torch.from_numpy(embed).float(), lengths
    ##return torch.tensor(embed).cuda()
    return torch.tensor(nli_net.encoder.encode(batch)).cuda()

# %%
def trainepoch(epoch):
    print('\nTRAINING : Epoch ' + str(epoch))
    nli_net.train()
    all_costs = []
    logs = []
    words_count = 0
    
    if epoch == 1:
        for param in nli_net.encoder.parameters():
            param.requires_grad = False

    last_time = time.time()
    correct = 0.
    # shuffle the data
    permutation = np.random.permutation(len(train['Sentence1']))

    #s1 = train['Sentence1'][permutation]
    #s2 = train['Sentence2'][permutation]
    #target = train['label'][permutation]
    s1, s2, target = [], [], []
    for idx in permutation:
      s1.append(train['Sentence1'][idx])
      s2.append(train['Sentence2'][idx])
      target.append(train['label'][idx])


    optimizer.param_groups[0]['lr'] = optimizer.param_groups[0]['lr'] * params.decay if epoch>1\
        and 'sgd' in params.optimizer else optimizer.param_groups[0]['lr']
    print('Learning rate : {0}'.format(optimizer.param_groups[0]['lr']))

    for stidx in range(0, len(s1), params.batch_size):
        # prepare batch
        #s1_batch, s1_len = get_batch(s1[stidx:stidx + params.batch_size],
        #                             word_vec, params.word_emb_dim)
        #s2_batch, s2_len = get_batch(s2[stidx:stidx + params.batch_size],
        #                             word_vec, params.word_emb_dim)
        #s1_batch, s2_batch = Variable(s1_batch.cuda()), Variable(s2_batch.cuda())
        #tgt_batch = Variable(torch.LongTensor(target[stidx:stidx + params.batch_size])).cuda()
        #k = s1_batch.size(1)  # actual batch size

        s1_batch = get_batch(s1[stidx:stidx + params.batch_size])
        s2_batch = get_batch(s2[stidx:stidx + params.batch_size])
        tgt_batch = torch.LongTensor(target[stidx:stidx + params.batch_size]).cuda()
        k = len(s1_batch)
        
        #u = torch.tensor(nli_net.encoder.encode(s1_batch)).float().cuda()
        #v = torch.tensor(nli_net.encoder.encode(s2_batch)).float().cuda()
        #print(f"u: {u.shape}")

        # model forward
        #output = nli_net((s1_batch, s1_len), (s2_batch, s2_len))
        output = nli_net(s1_batch, s2_batch)

        pred = output.data.max(1)[1]
        correct += pred.long().eq(tgt_batch.data.long()).cpu().sum()
        #print(len(pred))
        #print(len(s1[stidx:stidx + params.batch_size]))
        assert len(pred) == len(s1[stidx:stidx + params.batch_size])

        # loss
        loss = loss_fn(output, tgt_batch)
        #print(type(loss))
        all_costs.append(loss.item())  #.data[0])
        words_count += (s1_batch.nelement() + s2_batch.nelement()) / params.word_emb_dim

        # backward
        optimizer.zero_grad()
        loss.backward()

        # gradient clipping (off by default)
        #shrink_factor = 1
        #total_norm = 0

        #for p in nli_net.parameters():
        #    if p.requires_grad:
        #        p.grad.data.div_(k)  # divide by the actual batch size
        #        total_norm += p.grad.data.norm() ** 2
        #total_norm = np.sqrt(total_norm.cpu())

        #if total_norm > params.max_norm:
        #    shrink_factor = params.max_norm / total_norm
        #current_lr = optimizer.param_groups[0]['lr'] # current lr (no external "lr", for adam)
        #optimizer.param_groups[0]['lr'] = current_lr * shrink_factor # just for update

        # optimizer step
        optimizer.step()
        #optimizer.param_groups[0]['lr'] = current_lr

        if len(all_costs) == 100:
            logs.append('{0} ; loss {1} ; sentence/s {2} ; words/s {3} ; accuracy train : {4}'.format(
                            stidx, round(np.mean(all_costs), 2),
                            int(len(all_costs) * params.batch_size / (time.time() - last_time)),
                            int(words_count * 1.0 / (time.time() - last_time)),
                            100.*correct/(stidx+k)))
            print(logs[-1])
            last_time = time.time()
            words_count = 0
            all_costs = []
    train_acc = 100 * correct/len(s1)  #round(100 * correct/len(s1), 2)
    print('results : epoch {0} ; mean accuracy train : {1}'
          .format(epoch, train_acc))
    return train_acc

# %%
def evaluate(epoch, eval_type='valid', final_eval=False):
    nli_net.eval()
    correct = 0.
    global val_acc_best, lr, stop_training, adam_stop

    if eval_type == 'valid':
        print('\nVALIDATION : Epoch {0}'.format(epoch))

    s1 = valid['Sentence1'] if eval_type == 'valid' else test['Sentence1']
    s2 = valid['Sentence2'] if eval_type == 'valid' else test['Sentence2']
    target = valid['label'] if eval_type == 'valid' else test['label']
    #print(s1[0:0 + params.batch_size])
    #print('preloop')

    for q in range(0, len(s1), params.batch_size):
        # prepare batch
        #s1_batch, s1_len = get_batch(s1[i:i + params.batch_size], word_vec, params.word_emb_dim)
        #s2_batch, s2_len = get_batch(s2[i:i + params.batch_size], word_vec, params.word_emb_dim)
        #s1_batch, s2_batch = Variable(s1_batch.cuda()), Variable(s2_batch.cuda())
        #tgt_batch = Variable(torch.LongTensor(target[i:i + params.batch_size])).cuda()
        #print(s1[q:q + params.batch_size])
        #print(q)
        #print(params.batch_size)
        s1_batch = get_batch(s1[q:q + params.batch_size].tolist())
        s2_batch = get_batch(s2[q:q + params.batch_size].tolist())
        tgt_batch = torch.LongTensor(target[q:q + params.batch_size].tolist()).cuda()

        # model forward
        #output = nli_net((s1_batch, s1_len), (s2_batch, s2_len))
        output = nli_net(s1_batch, s2_batch)

        pred = output.data.max(1)[1]
        correct += pred.long().eq(tgt_batch.data.long()).cpu().sum()

        
    # save model
    eval_acc = 100 * correct/len(s1)  #round(100 * correct / len(s1), 2)
    if final_eval:
        print('finalgrep : accuracy {0} : {1}'.format(eval_type, eval_acc))
    else:
        print('togrep : results : epoch {0} ; mean accuracy {1} :\
              {2}'.format(epoch, eval_type, eval_acc))

    if eval_type == 'valid' and epoch <= params.n_epochs:
        if eval_acc > val_acc_best:
            print('saving model at epoch {0}'.format(epoch))
            if not os.path.exists(params.outputdir):
                os.makedirs(params.outputdir)
            torch.save(nli_net.state_dict(), os.path.join(params.outputdir,
                       params.outputmodelname))
            val_acc_best = eval_acc
        else:
            if 'sgd' in params.optimizer:
                optimizer.param_groups[0]['lr'] = optimizer.param_groups[0]['lr'] / params.lrshrink
                print('Shrinking lr by : {0}. New lr = {1}'
                      .format(params.lrshrink,
                              optimizer.param_groups[0]['lr']))
                if optimizer.param_groups[0]['lr'] < params.minlr:
                    stop_training = True
            if 'adam' in params.optimizer:
                # early stopping (at 2nd decrease in accuracy)
                stop_training = adam_stop
                adam_stop = True
    return eval_acc

# %%
#for contuation of model training when needed
#optimizer.param_groups[0]['lr'] = 0.001

# %%
"""
Train model on Natural Language Inference task
"""
epoch = 1

while not stop_training and epoch <= params.n_epochs:
    train_acc = trainepoch(epoch)
    eval_acc = evaluate(epoch, 'valid')
    epoch += 1
# Out:
# TRAINING : Epoch 1
# Learning rate : 0.001
# 12672 ; loss 0.71 ; sentence/s 363 ; words/s 1861 ; accuracy train : 69.375
# 25472 ; loss 0.69 ; sentence/s 458 ; words/s 2346 ; accuracy train : 70.0859375
# 38272 ; loss 0.66 ; sentence/s 454 ; words/s 2327 ; accuracy train : 70.94010162353516
# 51072 ; loss 0.64 ; sentence/s 454 ; words/s 2326 ; accuracy train : 71.505859375
# 63872 ; loss 0.63 ; sentence/s 453 ; words/s 2323 ; accuracy train : 71.9124984741211
# 76672 ; loss 0.64 ; sentence/s 453 ; words/s 2319 ; accuracy train : 72.125
# 89472 ; loss 0.63 ; sentence/s 454 ; words/s 2325 ; accuracy train : 72.33928680419922
# 102272 ; loss 0.63 ; sentence/s 450 ; words/s 2304 ; accuracy train : 72.5400390625
# 115072 ; loss 0.62 ; sentence/s 451 ; words/s 2313 ; accuracy train : 72.75086975097656
# 127872 ; loss 0.62 ; sentence/s 459 ; words/s 2354 ; accuracy train : 72.9242172241211
# 140672 ; loss 0.61 ; sentence/s 453 ; words/s 2323 ; accuracy train : 73.0632095336914
# 153472 ; loss 0.62 ; sentence/s 459 ; words/s 2351 ; accuracy train : 73.16471099853516
# 166272 ; loss 0.61 ; sentence/s 452 ; words/s 2318 ; accuracy train : 73.28425598144531
# 179072 ; loss 0.61 ; sentence/s 452 ; words/s 2318 ; accuracy train : 73.3671875
# 191872 ; loss 0.61 ; sentence/s 452 ; words/s 2316 ; accuracy train : 73.47447967529297
# 204672 ; loss 0.6 ; sentence/s 452 ; words/s 2318 ; accuracy train : 73.5517578125
# 217472 ; loss 0.6 ; sentence/s 454 ; words/s 2325 ; accuracy train : 73.64476013183594
# 230272 ; loss 0.6 ; sentence/s 459 ; words/s 2355 ; accuracy train : 73.71614837646484
# 243072 ; loss 0.6 ; sentence/s 462 ; words/s 2365 ; accuracy train : 73.79317474365234
# 255872 ; loss 0.59 ; sentence/s 450 ; words/s 2306 ; accuracy train : 73.87812805175781
# 268672 ; loss 0.6 ; sentence/s 452 ; words/s 2316 ; accuracy train : 73.92857360839844
# 281472 ; loss 0.6 ; sentence/s 453 ; words/s 2320 ; accuracy train : 73.97407531738281
# 294272 ; loss 0.6 ; sentence/s 451 ; words/s 2311 ; accuracy train : 74.02072143554688
# 307072 ; loss 0.57 ; sentence/s 451 ; words/s 2309 ; accuracy train : 74.11328125
# 319872 ; loss 0.6 ; sentence/s 455 ; words/s 2331 ; accuracy train : 74.15249633789062
# 332672 ; loss 0.59 ; sentence/s 455 ; words/s 2332 ; accuracy train : 74.20732879638672
# 345472 ; loss 0.58 ; sentence/s 454 ; words/s 2328 ; accuracy train : 74.26128387451172
# 358272 ; loss 0.58 ; sentence/s 456 ; words/s 2337 ; accuracy train : 74.31864166259766
# 371072 ; loss 0.59 ; sentence/s 457 ; words/s 2342 ; accuracy train : 74.36125946044922
# 383872 ; loss 0.58 ; sentence/s 454 ; words/s 2329 ; accuracy train : 74.40129852294922
# 396672 ; loss 0.57 ; sentence/s 450 ; words/s 2305 ; accuracy train : 74.4420394897461
# 409472 ; loss 0.58 ; sentence/s 451 ; words/s 2310 ; accuracy train : 74.484375
# 422272 ; loss 0.58 ; sentence/s 447 ; words/s 2291 ; accuracy train : 74.52391052246094
# 435072 ; loss 0.58 ; sentence/s 457 ; words/s 2340 ; accuracy train : 74.58455657958984
# 447872 ; loss 0.57 ; sentence/s 452 ; words/s 2316 ; accuracy train : 74.6330337524414
# 460672 ; loss 0.58 ; sentence/s 452 ; words/s 2315 ; accuracy train : 74.67208862304688
# 473472 ; loss 0.58 ; sentence/s 453 ; words/s 2321 ; accuracy train : 74.7060775756836
# 486272 ; loss 0.57 ; sentence/s 451 ; words/s 2313 ; accuracy train : 74.74053955078125
# 499072 ; loss 0.57 ; sentence/s 458 ; words/s 2345 ; accuracy train : 74.78064727783203
# 511872 ; loss 0.57 ; sentence/s 450 ; words/s 2308 ; accuracy train : 74.82832336425781
# 524672 ; loss 0.56 ; sentence/s 456 ; words/s 2336 ; accuracy train : 74.88147735595703
# 537472 ; loss 0.56 ; sentence/s 455 ; words/s 2330 ; accuracy train : 74.92224884033203
# results : epoch 1 ; mean accuracy train : 74.96300506591797
#
# VALIDATION : Epoch 1
# togrep : results : epoch 1 ; mean accuracy valid :              77.63665771484375
# saving model at epoch 1
#
# TRAINING : Epoch 2
# Learning rate : 0.001
# 12672 ; loss 0.55 ; sentence/s 356 ; words/s 1827 ; accuracy train : 76.6875
# 25472 ; loss 0.55 ; sentence/s 453 ; words/s 2323 ; accuracy train : 77.23828125
# 38272 ; loss 0.55 ; sentence/s 457 ; words/s 2340 ; accuracy train : 77.15885162353516
# 51072 ; loss 0.56 ; sentence/s 456 ; words/s 2336 ; accuracy train : 77.056640625
# 63872 ; loss 0.55 ; sentence/s 449 ; words/s 2303 ; accuracy train : 77.0796890258789
# 76672 ; loss 0.56 ; sentence/s 455 ; words/s 2332 ; accuracy train : 76.98828125
# 89472 ; loss 0.54 ; sentence/s 453 ; words/s 2323 ; accuracy train : 77.0625
# 102272 ; loss 0.55 ; sentence/s 454 ; words/s 2324 ; accuracy train : 77.0146484375
# 115072 ; loss 0.56 ; sentence/s 454 ; words/s 2325 ; accuracy train : 76.95052337646484
# 127872 ; loss 0.55 ; sentence/s 450 ; words/s 2306 ; accuracy train : 76.9976577758789
# 140672 ; loss 0.55 ; sentence/s 451 ; words/s 2313 ; accuracy train : 77.0071029663086
# 153472 ; loss 0.56 ; sentence/s 454 ; words/s 2326 ; accuracy train : 76.99088287353516
# 166272 ; loss 0.55 ; sentence/s 451 ; words/s 2312 ; accuracy train : 77.00841522216797
# 179072 ; loss 0.56 ; sentence/s 453 ; words/s 2324 ; accuracy train : 76.98548889160156
# 191872 ; loss 0.56 ; sentence/s 452 ; words/s 2316 ; accuracy train : 76.99687194824219
# 204672 ; loss 0.54 ; sentence/s 454 ; words/s 2325 ; accuracy train : 77.02197265625
# 217472 ; loss 0.54 ; sentence/s 448 ; words/s 2294 ; accuracy train : 77.02527618408203
# 230272 ; loss 0.54 ; sentence/s 440 ; words/s 2253 ; accuracy train : 77.04861450195312
# 243072 ; loss 0.54 ; sentence/s 440 ; words/s 2252 ; accuracy train : 77.08634948730469
# 255872 ; loss 0.55 ; sentence/s 440 ; words/s 2256 ; accuracy train : 77.05859375
# 268672 ; loss 0.54 ; sentence/s 439 ; words/s 2249 ; accuracy train : 77.07998657226562
# 281472 ; loss 0.54 ; sentence/s 449 ; words/s 2303 ; accuracy train : 77.1022720336914
# 294272 ; loss 0.54 ; sentence/s 441 ; words/s 2258 ; accuracy train : 77.12975311279297
# 307072 ; loss 0.54 ; sentence/s 446 ; words/s 2285 ; accuracy train : 77.14974212646484
# 319872 ; loss 0.54 ; sentence/s 444 ; words/s 2274 ; accuracy train : 77.16937255859375
# 332672 ; loss 0.54 ; sentence/s 448 ; words/s 2297 ; accuracy train : 77.19290924072266
# 345472 ; loss 0.53 ; sentence/s 452 ; words/s 2314 ; accuracy train : 77.20370483398438
# 358272 ; loss 0.54 ; sentence/s 449 ; words/s 2303 ; accuracy train : 77.23604583740234
# 371072 ; loss 0.54 ; sentence/s 459 ; words/s 2353 ; accuracy train : 77.25054168701172
# 383872 ; loss 0.54 ; sentence/s 450 ; words/s 2305 ; accuracy train : 77.26067352294922
# 396672 ; loss 0.54 ; sentence/s 438 ; words/s 2246 ; accuracy train : 77.27469635009766
# 409472 ; loss 0.53 ; sentence/s 430 ; words/s 2206 ; accuracy train : 77.28662109375
# 422272 ; loss 0.54 ; sentence/s 440 ; words/s 2255 ; accuracy train : 77.30516052246094
# 435072 ; loss 0.54 ; sentence/s 445 ; words/s 2279 ; accuracy train : 77.31227111816406
# 447872 ; loss 0.54 ; sentence/s 445 ; words/s 2282 ; accuracy train : 77.31652069091797
# 460672 ; loss 0.53 ; sentence/s 446 ; words/s 2287 ; accuracy train : 77.32920837402344
# 473472 ; loss 0.53 ; sentence/s 445 ; words/s 2279 ; accuracy train : 77.33678436279297
# 486272 ; loss 0.53 ; sentence/s 445 ; words/s 2280 ; accuracy train : 77.35670471191406
# 499072 ; loss 0.54 ; sentence/s 447 ; words/s 2291 ; accuracy train : 77.36518096923828
# 511872 ; loss 0.53 ; sentence/s 448 ; words/s 2294 ; accuracy train : 77.3736343383789
# 524672 ; loss 0.52 ; sentence/s 447 ; words/s 2290 ; accuracy train : 77.3993911743164
# 537472 ; loss 0.53 ; sentence/s 443 ; words/s 2269 ; accuracy train : 77.4125747680664
# results : epoch 2 ; mean accuracy train : 77.4181900024414
#
# VALIDATION : Epoch 2
# togrep : results : epoch 2 ; mean accuracy valid :              78.89656829833984
# saving model at epoch 2
#
# TRAINING : Epoch 3
# Learning rate : 0.001
# 12672 ; loss 0.52 ; sentence/s 352 ; words/s 1806 ; accuracy train : 77.796875
# 25472 ; loss 0.53 ; sentence/s 449 ; words/s 2300 ; accuracy train : 78.21875
# 38272 ; loss 0.52 ; sentence/s 447 ; words/s 2292 ; accuracy train : 78.25
# 51072 ; loss 0.52 ; sentence/s 445 ; words/s 2279 ; accuracy train : 78.314453125
# 63872 ; loss 0.52 ; sentence/s 440 ; words/s 2255 ; accuracy train : 78.39530944824219
# 76672 ; loss 0.52 ; sentence/s 443 ; words/s 2272 ; accuracy train : 78.34114837646484
# 89472 ; loss 0.53 ; sentence/s 443 ; words/s 2272 ; accuracy train : 78.33928680419922
# 102272 ; loss 0.52 ; sentence/s 449 ; words/s 2303 ; accuracy train : 78.3232421875
# 115072 ; loss 0.52 ; sentence/s 453 ; words/s 2319 ; accuracy train : 78.32465362548828
# 127872 ; loss 0.53 ; sentence/s 445 ; words/s 2279 ; accuracy train : 78.36405944824219
# 140672 ; loss 0.53 ; sentence/s 442 ; words/s 2265 ; accuracy train : 78.39346313476562
# 153472 ; loss 0.52 ; sentence/s 451 ; words/s 2310 ; accuracy train : 78.421875
# 166272 ; loss 0.52 ; sentence/s 445 ; words/s 2280 ; accuracy train : 78.40023803710938
# 179072 ; loss 0.52 ; sentence/s 446 ; words/s 2286 ; accuracy train : 78.43526458740234
# 191872 ; loss 0.53 ; sentence/s 451 ; words/s 2312 ; accuracy train : 78.41093444824219
# 204672 ; loss 0.51 ; sentence/s 442 ; words/s 2267 ; accuracy train : 78.45361328125
# 217472 ; loss 0.51 ; sentence/s 440 ; words/s 2254 ; accuracy train : 78.48023986816406
# 230272 ; loss 0.52 ; sentence/s 450 ; words/s 2304 ; accuracy train : 78.50650787353516
# 243072 ; loss 0.53 ; sentence/s 445 ; words/s 2280 ; accuracy train : 78.49053955078125
# 255872 ; loss 0.51 ; sentence/s 443 ; words/s 2270 ; accuracy train : 78.50077819824219
# 268672 ; loss 0.51 ; sentence/s 443 ; words/s 2268 ; accuracy train : 78.54315185546875
# 281472 ; loss 0.52 ; sentence/s 439 ; words/s 2247 ; accuracy train : 78.5539779663086
# 294272 ; loss 0.52 ; sentence/s 447 ; words/s 2292 ; accuracy train : 78.53736114501953
# 307072 ; loss 0.52 ; sentence/s 452 ; words/s 2316 ; accuracy train : 78.53060150146484
# 319872 ; loss 0.51 ; sentence/s 445 ; words/s 2283 ; accuracy train : 78.546875
# 332672 ; loss 0.52 ; sentence/s 438 ; words/s 2246 ; accuracy train : 78.54476928710938
# 345472 ; loss 0.5 ; sentence/s 438 ; words/s 2246 ; accuracy train : 78.58304595947266
# 358272 ; loss 0.51 ; sentence/s 431 ; words/s 2209 ; accuracy train : 78.57923889160156
# 371072 ; loss 0.51 ; sentence/s 428 ; words/s 2193 ; accuracy train : 78.58674621582031
# 383872 ; loss 0.5 ; sentence/s 442 ; words/s 2267 ; accuracy train : 78.61145782470703
# 396672 ; loss 0.5 ; sentence/s 449 ; words/s 2300 ; accuracy train : 78.64037322998047
# 409472 ; loss 0.51 ; sentence/s 440 ; words/s 2255 ; accuracy train : 78.646728515625
# 422272 ; loss 0.51 ; sentence/s 438 ; words/s 2243 ; accuracy train : 78.66998291015625
# 435072 ; loss 0.51 ; sentence/s 439 ; words/s 2247 ; accuracy train : 78.68795776367188
# 447872 ; loss 0.52 ; sentence/s 448 ; words/s 2297 ; accuracy train : 78.69285583496094
# 460672 ; loss 0.51 ; sentence/s 452 ; words/s 2314 ; accuracy train : 78.70030212402344
# 473472 ; loss 0.51 ; sentence/s 453 ; words/s 2323 ; accuracy train : 78.70735168457031
# 486272 ; loss 0.5 ; sentence/s 448 ; words/s 2296 ; accuracy train : 78.72821044921875
# 499072 ; loss 0.5 ; sentence/s 451 ; words/s 2310 ; accuracy train : 78.74959564208984
# 511872 ; loss 0.52 ; sentence/s 442 ; words/s 2266 ; accuracy train : 78.75410461425781
# 524672 ; loss 0.52 ; sentence/s 446 ; words/s 2287 ; accuracy train : 78.7530517578125
# 537472 ; loss 0.5 ; sentence/s 448 ; words/s 2296 ; accuracy train : 78.77232360839844
# results : epoch 3 ; mean accuracy train : 78.77284240722656
#
# VALIDATION : Epoch 3
# togrep : results : epoch 3 ; mean accuracy valid :              79.83133697509766
# saving model at epoch 3
#
# TRAINING : Epoch 4
# Learning rate : 0.001
# 12672 ; loss 0.5 ; sentence/s 351 ; words/s 1800 ; accuracy train : 79.3671875
# 25472 ; loss 0.48 ; sentence/s 447 ; words/s 2290 ; accuracy train : 79.7890625
# 38272 ; loss 0.49 ; sentence/s 436 ; words/s 2233 ; accuracy train : 79.95572662353516
# 51072 ; loss 0.5 ; sentence/s 455 ; words/s 2333 ; accuracy train : 79.875
# 63872 ; loss 0.49 ; sentence/s 442 ; words/s 2263 ; accuracy train : 79.83906555175781
# 76672 ; loss 0.49 ; sentence/s 444 ; words/s 2275 ; accuracy train : 79.80599212646484
# 89472 ; loss 0.49 ; sentence/s 443 ; words/s 2269 ; accuracy train : 79.83482360839844
# 102272 ; loss 0.51 ; sentence/s 444 ; words/s 2277 ; accuracy train : 79.78515625
# 115072 ; loss 0.48 ; sentence/s 439 ; words/s 2250 ; accuracy train : 79.84982299804688
# 127872 ; loss 0.5 ; sentence/s 449 ; words/s 2299 ; accuracy train : 79.7789077758789
# 140672 ; loss 0.5 ; sentence/s 449 ; words/s 2299 ; accuracy train : 79.73721313476562
# 153472 ; loss 0.5 ; sentence/s 450 ; words/s 2305 ; accuracy train : 79.71875
# 166272 ; loss 0.5 ; sentence/s 450 ; words/s 2306 ; accuracy train : 79.73918151855469
# 179072 ; loss 0.49 ; sentence/s 446 ; words/s 2286 ; accuracy train : 79.73828125
# 191872 ; loss 0.49 ; sentence/s 449 ; words/s 2303 ; accuracy train : 79.77291870117188
# 204672 ; loss 0.49 ; sentence/s 444 ; words/s 2276 ; accuracy train : 79.76416015625
# 217472 ; loss 0.48 ; sentence/s 439 ; words/s 2251 ; accuracy train : 79.79641723632812
# 230272 ; loss 0.49 ; sentence/s 450 ; words/s 2305 ; accuracy train : 79.81033325195312
# 243072 ; loss 0.48 ; sentence/s 448 ; words/s 2294 ; accuracy train : 79.83306121826172
# 255872 ; loss 0.5 ; sentence/s 436 ; words/s 2233 ; accuracy train : 79.84765625
# 268672 ; loss 0.49 ; sentence/s 437 ; words/s 2239 ; accuracy train : 79.8374252319336
# 281472 ; loss 0.49 ; sentence/s 432 ; words/s 2214 ; accuracy train : 79.83557891845703
# 294272 ; loss 0.49 ; sentence/s 438 ; words/s 2244 ; accuracy train : 79.84952545166016
# 307072 ; loss 0.5 ; sentence/s 433 ; words/s 2220 ; accuracy train : 79.81771087646484
# 319872 ; loss 0.51 ; sentence/s 434 ; words/s 2225 ; accuracy train : 79.77749633789062
# 332672 ; loss 0.49 ; sentence/s 436 ; words/s 2237 ; accuracy train : 79.77313995361328
# 345472 ; loss 0.49 ; sentence/s 452 ; words/s 2315 ; accuracy train : 79.77545928955078
# 358272 ; loss 0.49 ; sentence/s 453 ; words/s 2321 ; accuracy train : 79.77734375
# 371072 ; loss 0.48 ; sentence/s 457 ; words/s 2344 ; accuracy train : 79.80307006835938
# 383872 ; loss 0.49 ; sentence/s 459 ; words/s 2352 ; accuracy train : 79.8218765258789
# 396672 ; loss 0.48 ; sentence/s 449 ; words/s 2303 ; accuracy train : 79.85030364990234
# 409472 ; loss 0.49 ; sentence/s 439 ; words/s 2252 ; accuracy train : 79.86376953125
# 422272 ; loss 0.5 ; sentence/s 440 ; words/s 2253 ; accuracy train : 79.84990692138672
# 435072 ; loss 0.5 ; sentence/s 436 ; words/s 2234 ; accuracy train : 79.84030151367188
# 447872 ; loss 0.48 ; sentence/s 435 ; words/s 2227 ; accuracy train : 79.86629486083984
# 460672 ; loss 0.49 ; sentence/s 436 ; words/s 2235 ; accuracy train : 79.86675262451172
# 473472 ; loss 0.49 ; sentence/s 448 ; words/s 2293 ; accuracy train : 79.87141418457031
# 486272 ; loss 0.49 ; sentence/s 435 ; words/s 2229 ; accuracy train : 79.87335205078125
# 499072 ; loss 0.5 ; sentence/s 450 ; words/s 2307 ; accuracy train : 79.86277770996094
# 511872 ; loss 0.49 ; sentence/s 448 ; words/s 2296 ; accuracy train : 79.87675476074219
# 524672 ; loss 0.5 ; sentence/s 428 ; words/s 2191 ; accuracy train : 79.87633514404297
# 537472 ; loss 0.49 ; sentence/s 438 ; words/s 2244 ; accuracy train : 79.87518310546875
# results : epoch 4 ; mean accuracy train : 79.86901092529297
#
# VALIDATION : Epoch 4
# togrep : results : epoch 4 ; mean accuracy valid :              80.61369323730469
# saving model at epoch 4
#
# TRAINING : Epoch 5
# Learning rate : 0.001
# 12672 ; loss 0.47 ; sentence/s 348 ; words/s 1782 ; accuracy train : 80.25
# 25472 ; loss 0.48 ; sentence/s 435 ; words/s 2227 ; accuracy train : 80.39453125
# 38272 ; loss 0.48 ; sentence/s 430 ; words/s 2205 ; accuracy train : 80.3359375
# 51072 ; loss 0.47 ; sentence/s 437 ; words/s 2242 ; accuracy train : 80.458984375
# 63872 ; loss 0.48 ; sentence/s 432 ; words/s 2213 ; accuracy train : 80.5
# 76672 ; loss 0.47 ; sentence/s 440 ; words/s 2257 ; accuracy train : 80.60416412353516
# 89472 ; loss 0.47 ; sentence/s 453 ; words/s 2319 ; accuracy train : 80.67411041259766
# 102272 ; loss 0.48 ; sentence/s 452 ; words/s 2319 ; accuracy train : 80.6279296875
# 115072 ; loss 0.47 ; sentence/s 455 ; words/s 2331 ; accuracy train : 80.62152862548828
# 127872 ; loss 0.46 ; sentence/s 450 ; words/s 2305 ; accuracy train : 80.6937484741211
# 140672 ; loss 0.47 ; sentence/s 454 ; words/s 2328 ; accuracy train : 80.75426483154297
# 153472 ; loss 0.47 ; sentence/s 449 ; words/s 2299 ; accuracy train : 80.8203125
# 166272 ; loss 0.46 ; sentence/s 454 ; words/s 2328 ; accuracy train : 80.85816955566406
# 179072 ; loss 0.47 ; sentence/s 453 ; words/s 2322 ; accuracy train : 80.83258819580078
# 191872 ; loss 0.48 ; sentence/s 451 ; words/s 2309 ; accuracy train : 80.78437805175781
# 204672 ; loss 0.48 ; sentence/s 451 ; words/s 2311 ; accuracy train : 80.7666015625
# 217472 ; loss 0.48 ; sentence/s 449 ; words/s 2303 ; accuracy train : 80.76103210449219
# 230272 ; loss 0.48 ; sentence/s 454 ; words/s 2328 ; accuracy train : 80.73828125
# 243072 ; loss 0.48 ; sentence/s 445 ; words/s 2282 ; accuracy train : 80.7006607055664
# 255872 ; loss 0.47 ; sentence/s 451 ; words/s 2312 ; accuracy train : 80.69804382324219
# 268672 ; loss 0.47 ; sentence/s 454 ; words/s 2327 ; accuracy train : 80.70572662353516
# 281472 ; loss 0.48 ; sentence/s 447 ; words/s 2291 ; accuracy train : 80.68359375
# 294272 ; loss 0.48 ; sentence/s 451 ; words/s 2309 ; accuracy train : 80.69055938720703
# 307072 ; loss 0.48 ; sentence/s 446 ; words/s 2288 ; accuracy train : 80.66764068603516
# 319872 ; loss 0.49 ; sentence/s 442 ; words/s 2264 ; accuracy train : 80.64968872070312
# 332672 ; loss 0.47 ; sentence/s 447 ; words/s 2292 ; accuracy train : 80.65925598144531
# 345472 ; loss 0.48 ; sentence/s 446 ; words/s 2285 ; accuracy train : 80.66319274902344
# 358272 ; loss 0.48 ; sentence/s 453 ; words/s 2323 ; accuracy train : 80.65457916259766
# 371072 ; loss 0.48 ; sentence/s 450 ; words/s 2308 ; accuracy train : 80.6481704711914
# 383872 ; loss 0.48 ; sentence/s 452 ; words/s 2315 ; accuracy train : 80.6328125
# 396672 ; loss 0.47 ; sentence/s 444 ; words/s 2274 ; accuracy train : 80.64440155029297
# 409472 ; loss 0.47 ; sentence/s 452 ; words/s 2317 ; accuracy train : 80.6552734375
# 422272 ; loss 0.47 ; sentence/s 450 ; words/s 2308 ; accuracy train : 80.6711654663086
# 435072 ; loss 0.48 ; sentence/s 446 ; words/s 2285 ; accuracy train : 80.66865539550781
# 447872 ; loss 0.47 ; sentence/s 451 ; words/s 2311 ; accuracy train : 80.66785430908203
# 460672 ; loss 0.47 ; sentence/s 442 ; words/s 2265 ; accuracy train : 80.66861724853516
# 473472 ; loss 0.47 ; sentence/s 445 ; words/s 2283 ; accuracy train : 80.67272186279297
# 486272 ; loss 0.47 ; sentence/s 439 ; words/s 2252 ; accuracy train : 80.68030548095703
# 499072 ; loss 0.48 ; sentence/s 438 ; words/s 2243 ; accuracy train : 80.67488098144531
# 511872 ; loss 0.48 ; sentence/s 449 ; words/s 2303 ; accuracy train : 80.6683578491211
# 524672 ; loss 0.47 ; sentence/s 442 ; words/s 2266 ; accuracy train : 80.66749572753906
# 537472 ; loss 0.48 ; sentence/s 450 ; words/s 2308 ; accuracy train : 80.65978240966797
# results : epoch 5 ; mean accuracy train : 80.65991973876953
#
# VALIDATION : Epoch 5
# togrep : results : epoch 5 ; mean accuracy valid :              80.93883514404297
# saving model at epoch 5
#
# TRAINING : Epoch 6
# Learning rate : 0.001
# 12672 ; loss 0.45 ; sentence/s 352 ; words/s 1804 ; accuracy train : 81.734375
# 25472 ; loss 0.46 ; sentence/s 446 ; words/s 2287 ; accuracy train : 81.484375
# 38272 ; loss 0.46 ; sentence/s 449 ; words/s 2299 ; accuracy train : 81.3828125
# 51072 ; loss 0.46 ; sentence/s 444 ; words/s 2273 ; accuracy train : 81.3125
# 63872 ; loss 0.46 ; sentence/s 446 ; words/s 2284 ; accuracy train : 81.4156265258789
# 76672 ; loss 0.47 ; sentence/s 439 ; words/s 2251 ; accuracy train : 81.33984375
# 89472 ; loss 0.46 ; sentence/s 452 ; words/s 2318 ; accuracy train : 81.29911041259766
# 102272 ; loss 0.45 ; sentence/s 446 ; words/s 2288 ; accuracy train : 81.3466796875
# 115072 ; loss 0.46 ; sentence/s 442 ; words/s 2264 ; accuracy train : 81.35069274902344
# 127872 ; loss 0.47 ; sentence/s 446 ; words/s 2285 ; accuracy train : 81.36640930175781
# 140672 ; loss 0.45 ; sentence/s 449 ; words/s 2301 ; accuracy train : 81.37854766845703
# 153472 ; loss 0.46 ; sentence/s 451 ; words/s 2311 ; accuracy train : 81.36978912353516
# 166272 ; loss 0.44 ; sentence/s 446 ; words/s 2285 ; accuracy train : 81.42548370361328
# 179072 ; loss 0.47 ; sentence/s 448 ; words/s 2296 ; accuracy train : 81.41517639160156
# 191872 ; loss 0.46 ; sentence/s 448 ; words/s 2297 ; accuracy train : 81.4046859741211
# 204672 ; loss 0.46 ; sentence/s 448 ; words/s 2295 ; accuracy train : 81.4228515625
# 217472 ; loss 0.46 ; sentence/s 451 ; words/s 2310 ; accuracy train : 81.40625
# 230272 ; loss 0.46 ; sentence/s 447 ; words/s 2293 ; accuracy train : 81.39627075195312
# 243072 ; loss 0.46 ; sentence/s 443 ; words/s 2272 ; accuracy train : 81.3959732055664
# 255872 ; loss 0.48 ; sentence/s 449 ; words/s 2301 ; accuracy train : 81.35078430175781
# 268672 ; loss 0.46 ; sentence/s 443 ; words/s 2271 ; accuracy train : 81.32737731933594
# 281472 ; loss 0.47 ; sentence/s 442 ; words/s 2263 ; accuracy train : 81.3125
# 294272 ; loss 0.46 ; sentence/s 446 ; words/s 2284 ; accuracy train : 81.2965316772461
# 307072 ; loss 0.46 ; sentence/s 444 ; words/s 2275 ; accuracy train : 81.28678131103516
# 319872 ; loss 0.47 ; sentence/s 446 ; words/s 2283 ; accuracy train : 81.26094055175781
# 332672 ; loss 0.47 ; sentence/s 447 ; words/s 2292 ; accuracy train : 81.24579620361328
# 345472 ; loss 0.46 ; sentence/s 450 ; words/s 2308 ; accuracy train : 81.25086975097656
# 358272 ; loss 0.47 ; sentence/s 444 ; words/s 2277 ; accuracy train : 81.244140625
# 371072 ; loss 0.48 ; sentence/s 443 ; words/s 2272 ; accuracy train : 81.22279357910156
# 383872 ; loss 0.47 ; sentence/s 442 ; words/s 2267 ; accuracy train : 81.21926879882812
# 396672 ; loss 0.47 ; sentence/s 439 ; words/s 2248 ; accuracy train : 81.21925354003906
# 409472 ; loss 0.45 ; sentence/s 450 ; words/s 2304 ; accuracy train : 81.24609375
# 422272 ; loss 0.45 ; sentence/s 435 ; words/s 2232 ; accuracy train : 81.2571029663086
# 435072 ; loss 0.46 ; sentence/s 436 ; words/s 2234 ; accuracy train : 81.24540710449219
# 447872 ; loss 0.47 ; sentence/s 433 ; words/s 2217 ; accuracy train : 81.2406234741211
# 460672 ; loss 0.46 ; sentence/s 427 ; words/s 2186 ; accuracy train : 81.24131774902344
# 473472 ; loss 0.48 ; sentence/s 431 ; words/s 2207 ; accuracy train : 81.22698211669922
# 486272 ; loss 0.45 ; sentence/s 435 ; words/s 2227 ; accuracy train : 81.23725128173828
# 499072 ; loss 0.47 ; sentence/s 438 ; words/s 2245 ; accuracy train : 81.2237548828125
# 511872 ; loss 0.46 ; sentence/s 434 ; words/s 2224 ; accuracy train : 81.22734069824219
# 524672 ; loss 0.46 ; sentence/s 434 ; words/s 2225 ; accuracy train : 81.22541809082031
# 537472 ; loss 0.44 ; sentence/s 440 ; words/s 2257 ; accuracy train : 81.24906921386719
# results : epoch 6 ; mean accuracy train : 81.23731231689453
#
# VALIDATION : Epoch 6
# togrep : results : epoch 6 ; mean accuracy valid :              81.17252349853516
# saving model at epoch 6
#
# TRAINING : Epoch 7
# Learning rate : 0.001
# 12672 ; loss 0.44 ; sentence/s 354 ; words/s 1815 ; accuracy train : 82.3828125
# 25472 ; loss 0.45 ; sentence/s 451 ; words/s 2312 ; accuracy train : 81.93359375
# 38272 ; loss 0.43 ; sentence/s 436 ; words/s 2232 ; accuracy train : 82.16927337646484
# 51072 ; loss 0.45 ; sentence/s 438 ; words/s 2246 ; accuracy train : 82.119140625
# 63872 ; loss 0.44 ; sentence/s 441 ; words/s 2262 ; accuracy train : 82.0765609741211
# 76672 ; loss 0.45 ; sentence/s 437 ; words/s 2239 ; accuracy train : 82.01432037353516
# 89472 ; loss 0.44 ; sentence/s 446 ; words/s 2285 ; accuracy train : 82.01227569580078
# 102272 ; loss 0.46 ; sentence/s 444 ; words/s 2273 ; accuracy train : 81.900390625
# 115072 ; loss 0.44 ; sentence/s 447 ; words/s 2290 ; accuracy train : 81.93402862548828
# 127872 ; loss 0.45 ; sentence/s 444 ; words/s 2276 ; accuracy train : 81.95390319824219
# 140672 ; loss 0.44 ; sentence/s 449 ; words/s 2303 ; accuracy train : 81.96520233154297
# 153472 ; loss 0.45 ; sentence/s 446 ; words/s 2284 ; accuracy train : 81.96744537353516
# 166272 ; loss 0.44 ; sentence/s 443 ; words/s 2269 ; accuracy train : 81.98558044433594
# 179072 ; loss 0.43 ; sentence/s 441 ; words/s 2260 ; accuracy train : 82.02120208740234
# 191872 ; loss 0.45 ; sentence/s 448 ; words/s 2297 ; accuracy train : 82.02291870117188
# 204672 ; loss 0.45 ; sentence/s 452 ; words/s 2318 ; accuracy train : 82.01953125
# 217472 ; loss 0.45 ; sentence/s 440 ; words/s 2254 ; accuracy train : 82.00643157958984
# 230272 ; loss 0.45 ; sentence/s 440 ; words/s 2253 ; accuracy train : 81.97872924804688
# 243072 ; loss 0.44 ; sentence/s 443 ; words/s 2268 ; accuracy train : 81.99835205078125
# 255872 ; loss 0.44 ; sentence/s 448 ; words/s 2298 ; accuracy train : 82.00508117675781
# 268672 ; loss 0.44 ; sentence/s 435 ; words/s 2227 ; accuracy train : 82.01487731933594
# 281472 ; loss 0.45 ; sentence/s 444 ; words/s 2275 ; accuracy train : 82.00603485107422
# 294272 ; loss 0.45 ; sentence/s 443 ; words/s 2271 ; accuracy train : 82.01087188720703
# 307072 ; loss 0.45 ; sentence/s 446 ; words/s 2286 ; accuracy train : 82.00162506103516
# 319872 ; loss 0.46 ; sentence/s 444 ; words/s 2275 ; accuracy train : 81.97125244140625
# 332672 ; loss 0.46 ; sentence/s 427 ; words/s 2190 ; accuracy train : 81.94261169433594
# 345472 ; loss 0.46 ; sentence/s 441 ; words/s 2262 ; accuracy train : 81.92679595947266
# 358272 ; loss 0.44 ; sentence/s 444 ; words/s 2275 ; accuracy train : 81.92159271240234
# 371072 ; loss 0.44 ; sentence/s 447 ; words/s 2290 ; accuracy train : 81.93885040283203
# 383872 ; loss 0.44 ; sentence/s 440 ; words/s 2257 ; accuracy train : 81.94271087646484
# 396672 ; loss 0.45 ; sentence/s 448 ; words/s 2295 ; accuracy train : 81.93498229980469
# 409472 ; loss 0.45 ; sentence/s 447 ; words/s 2291 ; accuracy train : 81.94384765625
# 422272 ; loss 0.45 ; sentence/s 446 ; words/s 2283 ; accuracy train : 81.93702697753906
# 435072 ; loss 0.47 ; sentence/s 450 ; words/s 2307 ; accuracy train : 81.91842651367188
# 447872 ; loss 0.45 ; sentence/s 444 ; words/s 2276 ; accuracy train : 81.92298889160156
# 460672 ; loss 0.45 ; sentence/s 448 ; words/s 2298 ; accuracy train : 81.916015625
# 473472 ; loss 0.46 ; sentence/s 448 ; words/s 2296 ; accuracy train : 81.90118408203125
# 486272 ; loss 0.45 ; sentence/s 449 ; words/s 2300 ; accuracy train : 81.90254974365234
# 499072 ; loss 0.46 ; sentence/s 445 ; words/s 2282 ; accuracy train : 81.89042663574219
# 511872 ; loss 0.46 ; sentence/s 442 ; words/s 2265 ; accuracy train : 81.8857421875
# 524672 ; loss 0.45 ; sentence/s 444 ; words/s 2273 ; accuracy train : 81.88833618164062
# 537472 ; loss 0.45 ; sentence/s 441 ; words/s 2260 ; accuracy train : 81.890625
# results : epoch 7 ; mean accuracy train : 81.86767578125
#
# VALIDATION : Epoch 7
# togrep : results : epoch 7 ; mean accuracy valid :              81.45702362060547
# saving model at epoch 7
#
# TRAINING : Epoch 8
# Learning rate : 0.001
# 12672 ; loss 0.43 ; sentence/s 347 ; words/s 1776 ; accuracy train : 82.6640625
# 25472 ; loss 0.43 ; sentence/s 439 ; words/s 2251 ; accuracy train : 82.69140625
# 38272 ; loss 0.42 ; sentence/s 445 ; words/s 2280 ; accuracy train : 82.84114837646484
# 51072 ; loss 0.43 ; sentence/s 445 ; words/s 2282 ; accuracy train : 82.84765625
# 63872 ; loss 0.43 ; sentence/s 438 ; words/s 2247 ; accuracy train : 82.75468444824219
# 76672 ; loss 0.43 ; sentence/s 447 ; words/s 2289 ; accuracy train : 82.71875
# 89472 ; loss 0.44 ; sentence/s 435 ; words/s 2231 ; accuracy train : 82.68192291259766
# 102272 ; loss 0.43 ; sentence/s 439 ; words/s 2251 ; accuracy train : 82.6572265625
# 115072 ; loss 0.43 ; sentence/s 444 ; words/s 2276 ; accuracy train : 82.68142700195312
# 127872 ; loss 0.44 ; sentence/s 443 ; words/s 2269 ; accuracy train : 82.62187194824219
# 140672 ; loss 0.43 ; sentence/s 439 ; words/s 2247 ; accuracy train : 82.6335220336914
# 153472 ; loss 0.43 ; sentence/s 445 ; words/s 2283 ; accuracy train : 82.671875
# 166272 ; loss 0.44 ; sentence/s 440 ; words/s 2255 ; accuracy train : 82.64002227783203
# 179072 ; loss 0.43 ; sentence/s 445 ; words/s 2279 ; accuracy train : 82.66071319580078
# 191872 ; loss 0.44 ; sentence/s 442 ; words/s 2265 ; accuracy train : 82.62395477294922
# 204672 ; loss 0.44 ; sentence/s 446 ; words/s 2286 ; accuracy train : 82.609375
# 217472 ; loss 0.44 ; sentence/s 446 ; words/s 2286 ; accuracy train : 82.56663513183594
# 230272 ; loss 0.43 ; sentence/s 440 ; words/s 2256 ; accuracy train : 82.56771087646484
# 243072 ; loss 0.44 ; sentence/s 447 ; words/s 2292 ; accuracy train : 82.56620025634766
# 255872 ; loss 0.43 ; sentence/s 445 ; words/s 2281 ; accuracy train : 82.5562515258789
# 268672 ; loss 0.44 ; sentence/s 445 ; words/s 2279 ; accuracy train : 82.53385162353516
# 281472 ; loss 0.44 ; sentence/s 439 ; words/s 2248 ; accuracy train : 82.51029968261719
# 294272 ; loss 0.44 ; sentence/s 441 ; words/s 2261 ; accuracy train : 82.48980712890625
# 307072 ; loss 0.44 ; sentence/s 452 ; words/s 2317 ; accuracy train : 82.47135162353516
# 319872 ; loss 0.44 ; sentence/s 440 ; words/s 2253 ; accuracy train : 82.46937561035156
# 332672 ; loss 0.44 ; sentence/s 442 ; words/s 2266 ; accuracy train : 82.46183776855469
# 345472 ; loss 0.45 ; sentence/s 441 ; words/s 2261 ; accuracy train : 82.42881774902344
# 358272 ; loss 0.45 ; sentence/s 440 ; words/s 2257 ; accuracy train : 82.427734375
# 371072 ; loss 0.44 ; sentence/s 438 ; words/s 2247 ; accuracy train : 82.41729736328125
# 383872 ; loss 0.44 ; sentence/s 432 ; words/s 2215 ; accuracy train : 82.42135620117188
# 396672 ; loss 0.45 ; sentence/s 438 ; words/s 2245 ; accuracy train : 82.41708374023438
# 409472 ; loss 0.44 ; sentence/s 445 ; words/s 2279 ; accuracy train : 82.422607421875
# 422272 ; loss 0.44 ; sentence/s 449 ; words/s 2303 ; accuracy train : 82.42850494384766
# 435072 ; loss 0.44 ; sentence/s 451 ; words/s 2310 ; accuracy train : 82.42440032958984
# 447872 ; loss 0.44 ; sentence/s 440 ; words/s 2254 ; accuracy train : 82.41138458251953
# 460672 ; loss 0.45 ; sentence/s 449 ; words/s 2301 ; accuracy train : 82.38584899902344
# 473472 ; loss 0.45 ; sentence/s 420 ; words/s 2150 ; accuracy train : 82.3671875
# 486272 ; loss 0.43 ; sentence/s 445 ; words/s 2278 ; accuracy train : 82.38754272460938
# 499072 ; loss 0.45 ; sentence/s 448 ; words/s 2293 ; accuracy train : 82.37359619140625
# 511872 ; loss 0.44 ; sentence/s 449 ; words/s 2300 ; accuracy train : 82.3822250366211
# 524672 ; loss 0.45 ; sentence/s 443 ; words/s 2269 ; accuracy train : 82.36566162109375
# 537472 ; loss 0.44 ; sentence/s 444 ; words/s 2276 ; accuracy train : 82.36104583740234
# results : epoch 8 ; mean accuracy train : 82.3591537475586
#
# VALIDATION : Epoch 8
# togrep : results : epoch 8 ; mean accuracy valid :              81.7110366821289
# saving model at epoch 8
#
# TRAINING : Epoch 9
# Learning rate : 0.001
# 12672 ; loss 0.41 ; sentence/s 351 ; words/s 1800 ; accuracy train : 83.3203125
# 25472 ; loss 0.42 ; sentence/s 443 ; words/s 2271 ; accuracy train : 83.3671875
# 38272 ; loss 0.42 ; sentence/s 446 ; words/s 2284 ; accuracy train : 83.22135162353516
# 51072 ; loss 0.41 ; sentence/s 451 ; words/s 2309 ; accuracy train : 83.302734375
# 63872 ; loss 0.42 ; sentence/s 445 ; words/s 2281 ; accuracy train : 83.2828140258789
# 76672 ; loss 0.42 ; sentence/s 441 ; words/s 2260 ; accuracy train : 83.26041412353516
# 89472 ; loss 0.42 ; sentence/s 441 ; words/s 2261 ; accuracy train : 83.24330139160156
# 102272 ; loss 0.42 ; sentence/s 441 ; words/s 2259 ; accuracy train : 83.216796875
# 115072 ; loss 0.43 ; sentence/s 447 ; words/s 2291 ; accuracy train : 83.13975524902344
# 127872 ; loss 0.43 ; sentence/s 450 ; words/s 2308 ; accuracy train : 83.11015319824219
# 140672 ; loss 0.42 ; sentence/s 453 ; words/s 2324 ; accuracy train : 83.11363983154297
# 153472 ; loss 0.43 ; sentence/s 450 ; words/s 2305 ; accuracy train : 83.09505462646484
# 166272 ; loss 0.43 ; sentence/s 449 ; words/s 2300 ; accuracy train : 83.05048370361328
# 179072 ; loss 0.43 ; sentence/s 448 ; words/s 2297 ; accuracy train : 83.04520416259766
# 191872 ; loss 0.43 ; sentence/s 453 ; words/s 2319 ; accuracy train : 83.01094055175781
# 204672 ; loss 0.44 ; sentence/s 450 ; words/s 2307 ; accuracy train : 82.97119140625
# 217472 ; loss 0.42 ; sentence/s 450 ; words/s 2306 ; accuracy train : 82.98253631591797
# 230272 ; loss 0.43 ; sentence/s 227 ; words/s 1167 ; accuracy train : 82.95877075195312
# 243072 ; loss 0.42 ; sentence/s 152 ; words/s 781 ; accuracy train : 82.9399642944336
# 255872 ; loss 0.42 ; sentence/s 151 ; words/s 775 ; accuracy train : 82.9496078491211
# 268672 ; loss 0.43 ; sentence/s 150 ; words/s 772 ; accuracy train : 82.94456481933594
# 281472 ; loss 0.42 ; sentence/s 152 ; words/s 779 ; accuracy train : 82.94638061523438
# 294272 ; loss 0.41 ; sentence/s 150 ; words/s 768 ; accuracy train : 82.97758483886719
# 307072 ; loss 0.43 ; sentence/s 152 ; words/s 778 ; accuracy train : 82.974609375
# 319872 ; loss 0.43 ; sentence/s 152 ; words/s 778 ; accuracy train : 82.96937561035156
# 332672 ; loss 0.43 ; sentence/s 154 ; words/s 789 ; accuracy train : 82.95222473144531
# 345472 ; loss 0.42 ; sentence/s 153 ; words/s 787 ; accuracy train : 82.96701049804688
# 358272 ; loss 0.43 ; sentence/s 155 ; words/s 797 ; accuracy train : 82.95870208740234
# 371072 ; loss 0.44 ; sentence/s 154 ; words/s 789 ; accuracy train : 82.94207763671875
# 383872 ; loss 0.43 ; sentence/s 153 ; words/s 786 ; accuracy train : 82.92500305175781
# 396672 ; loss 0.43 ; sentence/s 154 ; words/s 788 ; accuracy train : 82.9070053100586
# 409472 ; loss 0.43 ; sentence/s 155 ; words/s 794 ; accuracy train : 82.889892578125
# 422272 ; loss 0.43 ; sentence/s 153 ; words/s 784 ; accuracy train : 82.88967895507812
# 435072 ; loss 0.43 ; sentence/s 153 ; words/s 788 ; accuracy train : 82.88304138183594
# 447872 ; loss 0.43 ; sentence/s 153 ; words/s 784 ; accuracy train : 82.89151763916016
# 460672 ; loss 0.44 ; sentence/s 154 ; words/s 791 ; accuracy train : 82.87239837646484
# 473472 ; loss 0.43 ; sentence/s 155 ; words/s 794 ; accuracy train : 82.86042785644531
# 486272 ; loss 0.43 ; sentence/s 154 ; words/s 791 ; accuracy train : 82.85464477539062
# 499072 ; loss 0.43 ; sentence/s 153 ; words/s 786 ; accuracy train : 82.8515625
# 511872 ; loss 0.44 ; sentence/s 153 ; words/s 784 ; accuracy train : 82.84159851074219
# 524672 ; loss 0.43 ; sentence/s 264 ; words/s 1354 ; accuracy train : 82.83250427246094
# 537472 ; loss 0.43 ; sentence/s 435 ; words/s 2231 ; accuracy train : 82.8203125
# results : epoch 9 ; mean accuracy train : 82.81895446777344
#
# VALIDATION : Epoch 9
# togrep : results : epoch 9 ; mean accuracy valid :              81.84312438964844
# saving model at epoch 9
#
# TRAINING : Epoch 10
# Learning rate : 0.001
# 12672 ; loss 0.41 ; sentence/s 356 ; words/s 1823 ; accuracy train : 84.03125
# 25472 ; loss 0.4 ; sentence/s 446 ; words/s 2288 ; accuracy train : 83.9765625
# 38272 ; loss 0.39 ; sentence/s 455 ; words/s 2330 ; accuracy train : 84.19271087646484
# 51072 ; loss 0.41 ; sentence/s 446 ; words/s 2283 ; accuracy train : 84.12890625
# 63872 ; loss 0.41 ; sentence/s 452 ; words/s 2316 ; accuracy train : 84.0218734741211
# 76672 ; loss 0.4 ; sentence/s 450 ; words/s 2308 ; accuracy train : 83.92057037353516
# 89472 ; loss 0.42 ; sentence/s 449 ; words/s 2301 ; accuracy train : 83.80357360839844
# 102272 ; loss 0.41 ; sentence/s 452 ; words/s 2314 ; accuracy train : 83.7744140625
# 115072 ; loss 0.42 ; sentence/s 449 ; words/s 2299 ; accuracy train : 83.67534637451172
# 127872 ; loss 0.41 ; sentence/s 453 ; words/s 2320 ; accuracy train : 83.6539077758789
# 140672 ; loss 0.42 ; sentence/s 453 ; words/s 2321 ; accuracy train : 83.58451843261719
# 153472 ; loss 0.41 ; sentence/s 452 ; words/s 2318 ; accuracy train : 83.58853912353516
# 166272 ; loss 0.41 ; sentence/s 444 ; words/s 2276 ; accuracy train : 83.60095977783203
# 179072 ; loss 0.41 ; sentence/s 455 ; words/s 2332 ; accuracy train : 83.61663055419922
# 191872 ; loss 0.41 ; sentence/s 452 ; words/s 2317 ; accuracy train : 83.59739685058594
# 204672 ; loss 0.41 ; sentence/s 449 ; words/s 2301 ; accuracy train : 83.607421875
# 217472 ; loss 0.42 ; sentence/s 451 ; words/s 2311 ; accuracy train : 83.58915710449219
# 230272 ; loss 0.42 ; sentence/s 448 ; words/s 2295 ; accuracy train : 83.55165100097656
# 243072 ; loss 0.41 ; sentence/s 449 ; words/s 2299 ; accuracy train : 83.55509948730469
# 255872 ; loss 0.41 ; sentence/s 454 ; words/s 2328 ; accuracy train : 83.5601577758789
# 268672 ; loss 0.43 ; sentence/s 455 ; words/s 2330 ; accuracy train : 83.53050231933594
# 281472 ; loss 0.42 ; sentence/s 451 ; words/s 2313 ; accuracy train : 83.51775360107422
# 294272 ; loss 0.42 ; sentence/s 451 ; words/s 2312 ; accuracy train : 83.51256561279297
# 307072 ; loss 0.43 ; sentence/s 456 ; words/s 2338 ; accuracy train : 83.47232818603516
# 319872 ; loss 0.42 ; sentence/s 445 ; words/s 2280 ; accuracy train : 83.47093963623047
# 332672 ; loss 0.42 ; sentence/s 454 ; words/s 2326 ; accuracy train : 83.46033477783203
# 345472 ; loss 0.43 ; sentence/s 444 ; words/s 2275 ; accuracy train : 83.43836975097656
# 358272 ; loss 0.42 ; sentence/s 455 ; words/s 2329 ; accuracy train : 83.43275451660156
# 371072 ; loss 0.41 ; sentence/s 451 ; words/s 2310 ; accuracy train : 83.43103790283203
# 383872 ; loss 0.42 ; sentence/s 450 ; words/s 2307 ; accuracy train : 83.41432189941406
# 396672 ; loss 0.42 ; sentence/s 452 ; words/s 2315 ; accuracy train : 83.40650177001953
# 409472 ; loss 0.42 ; sentence/s 453 ; words/s 2322 ; accuracy train : 83.392333984375
# 422272 ; loss 0.42 ; sentence/s 449 ; words/s 2301 ; accuracy train : 83.38375854492188
# 435072 ; loss 0.41 ; sentence/s 455 ; words/s 2329 ; accuracy train : 83.37799072265625
# 447872 ; loss 0.42 ; sentence/s 451 ; words/s 2310 ; accuracy train : 83.3607177734375
# 460672 ; loss 0.41 ; sentence/s 450 ; words/s 2305 ; accuracy train : 83.36392974853516
# 473472 ; loss 0.42 ; sentence/s 450 ; words/s 2304 ; accuracy train : 83.35050964355469
# 486272 ; loss 0.42 ; sentence/s 448 ; words/s 2295 ; accuracy train : 83.3458023071289
# 499072 ; loss 0.42 ; sentence/s 449 ; words/s 2303 ; accuracy train : 83.34575653076172
# 511872 ; loss 0.42 ; sentence/s 446 ; words/s 2286 ; accuracy train : 83.34101867675781
# 524672 ; loss 0.42 ; sentence/s 446 ; words/s 2285 ; accuracy train : 83.3389892578125
# 537472 ; loss 0.42 ; sentence/s 449 ; words/s 2300 ; accuracy train : 83.33370208740234
# results : epoch 10 ; mean accuracy train : 83.32444763183594
#
# VALIDATION : Epoch 10
# togrep : results : epoch 10 ; mean accuracy valid :              82.2292251586914
# saving model at epoch 10
#
# TRAINING : Epoch 11
# Learning rate : 0.001
# 12672 ; loss 0.39 ; sentence/s 358 ; words/s 1836 ; accuracy train : 84.34375
# 25472 ; loss 0.38 ; sentence/s 446 ; words/s 2284 ; accuracy train : 84.6953125
# 38272 ; loss 0.39 ; sentence/s 451 ; words/s 2314 ; accuracy train : 84.4609375
# 51072 ; loss 0.39 ; sentence/s 452 ; words/s 2315 ; accuracy train : 84.4765625
# 63872 ; loss 0.39 ; sentence/s 448 ; words/s 2295 ; accuracy train : 84.42500305175781
# 76672 ; loss 0.39 ; sentence/s 454 ; words/s 2328 ; accuracy train : 84.40885162353516
# 89472 ; loss 0.4 ; sentence/s 452 ; words/s 2315 ; accuracy train : 84.41517639160156
# 102272 ; loss 0.41 ; sentence/s 436 ; words/s 2235 ; accuracy train : 84.3134765625
# 115072 ; loss 0.4 ; sentence/s 440 ; words/s 2255 ; accuracy train : 84.29774475097656
# 127872 ; loss 0.41 ; sentence/s 443 ; words/s 2271 ; accuracy train : 84.21952819824219
# 140672 ; loss 0.41 ; sentence/s 443 ; words/s 2269 ; accuracy train : 84.18252563476562
# 153472 ; loss 0.4 ; sentence/s 450 ; words/s 2308 ; accuracy train : 84.162109375
# 166272 ; loss 0.41 ; sentence/s 445 ; words/s 2280 ; accuracy train : 84.13341522216797
# 179072 ; loss 0.41 ; sentence/s 454 ; words/s 2328 ; accuracy train : 84.10881805419922
# 191872 ; loss 0.4 ; sentence/s 450 ; words/s 2305 ; accuracy train : 84.09426879882812
# 204672 ; loss 0.41 ; sentence/s 442 ; words/s 2263 ; accuracy train : 84.0791015625
# 217472 ; loss 0.41 ; sentence/s 440 ; words/s 2253 ; accuracy train : 84.05055236816406
# 230272 ; loss 0.41 ; sentence/s 445 ; words/s 2279 ; accuracy train : 84.03081512451172
# 243072 ; loss 0.4 ; sentence/s 449 ; words/s 2301 ; accuracy train : 84.00822448730469
# 255872 ; loss 0.42 ; sentence/s 442 ; words/s 2263 ; accuracy train : 83.970703125
# 268672 ; loss 0.4 ; sentence/s 444 ; words/s 2275 ; accuracy train : 83.9828872680664
# 281472 ; loss 0.39 ; sentence/s 444 ; words/s 2275 ; accuracy train : 83.99573516845703
# 294272 ; loss 0.4 ; sentence/s 439 ; words/s 2249 ; accuracy train : 83.98743438720703
# 307072 ; loss 0.4 ; sentence/s 441 ; words/s 2259 ; accuracy train : 83.978515625
# 319872 ; loss 0.4 ; sentence/s 442 ; words/s 2267 ; accuracy train : 83.98656463623047
# 332672 ; loss 0.42 ; sentence/s 443 ; words/s 2272 ; accuracy train : 83.95433044433594
# 345472 ; loss 0.42 ; sentence/s 444 ; words/s 2274 ; accuracy train : 83.93634033203125
# 358272 ; loss 0.41 ; sentence/s 443 ; words/s 2271 ; accuracy train : 83.93610382080078
# 371072 ; loss 0.41 ; sentence/s 448 ; words/s 2297 ; accuracy train : 83.92618560791016
# 383872 ; loss 0.41 ; sentence/s 445 ; words/s 2283 ; accuracy train : 83.92526245117188
# 396672 ; loss 0.41 ; sentence/s 441 ; words/s 2261 ; accuracy train : 83.91104125976562
# 409472 ; loss 0.41 ; sentence/s 447 ; words/s 2290 ; accuracy train : 83.89990234375
# 422272 ; loss 0.4 ; sentence/s 447 ; words/s 2290 ; accuracy train : 83.89725494384766
# 435072 ; loss 0.42 ; sentence/s 444 ; words/s 2277 ; accuracy train : 83.87293243408203
# 447872 ; loss 0.42 ; sentence/s 434 ; words/s 2223 ; accuracy train : 83.8531265258789
# 460672 ; loss 0.42 ; sentence/s 441 ; words/s 2260 ; accuracy train : 83.82660675048828
# 473472 ; loss 0.4 ; sentence/s 446 ; words/s 2283 ; accuracy train : 83.8342514038086
# 486272 ; loss 0.41 ; sentence/s 447 ; words/s 2290 ; accuracy train : 83.83038330078125
# 499072 ; loss 0.42 ; sentence/s 454 ; words/s 2328 ; accuracy train : 83.80989837646484
# 511872 ; loss 0.42 ; sentence/s 447 ; words/s 2289 ; accuracy train : 83.796875
# 524672 ; loss 0.41 ; sentence/s 451 ; words/s 2310 ; accuracy train : 83.79020690917969
# 537472 ; loss 0.41 ; sentence/s 453 ; words/s 2323 ; accuracy train : 83.7875747680664
# results : epoch 11 ; mean accuracy train : 83.7787857055664
#
# VALIDATION : Epoch 11
# togrep : results : epoch 11 ; mean accuracy valid :              82.1174545288086
#
# TRAINING : Epoch 12
# Learning rate : 0.001
# 12672 ; loss 0.4 ; sentence/s 355 ; words/s 1818 ; accuracy train : 83.9453125
# 25472 ; loss 0.38 ; sentence/s 444 ; words/s 2277 ; accuracy train : 84.37890625
# 38272 ; loss 0.38 ; sentence/s 449 ; words/s 2299 ; accuracy train : 84.71614837646484
# 51072 ; loss 0.38 ; sentence/s 452 ; words/s 2318 ; accuracy train : 84.759765625
# 63872 ; loss 0.38 ; sentence/s 449 ; words/s 2299 ; accuracy train : 84.7796859741211
# 76672 ; loss 0.38 ; sentence/s 451 ; words/s 2313 ; accuracy train : 84.83203125
# 89472 ; loss 0.38 ; sentence/s 451 ; words/s 2312 ; accuracy train : 84.88504791259766
# 102272 ; loss 0.38 ; sentence/s 449 ; words/s 2302 ; accuracy train : 84.861328125
# 115072 ; loss 0.4 ; sentence/s 446 ; words/s 2283 ; accuracy train : 84.75434112548828
# 127872 ; loss 0.39 ; sentence/s 451 ; words/s 2313 ; accuracy train : 84.7437515258789
# 140672 ; loss 0.39 ; sentence/s 446 ; words/s 2288 ; accuracy train : 84.74360656738281
# 153472 ; loss 0.39 ; sentence/s 447 ; words/s 2289 ; accuracy train : 84.72786712646484
# 166272 ; loss 0.39 ; sentence/s 447 ; words/s 2289 ; accuracy train : 84.70673370361328
# 179072 ; loss 0.4 ; sentence/s 446 ; words/s 2287 ; accuracy train : 84.65122985839844
# 191872 ; loss 0.39 ; sentence/s 445 ; words/s 2279 ; accuracy train : 84.61405944824219
# 204672 ; loss 0.41 ; sentence/s 450 ; words/s 2304 ; accuracy train : 84.5634765625
# 217472 ; loss 0.39 ; sentence/s 448 ; words/s 2298 ; accuracy train : 84.5758285522461
# 230272 ; loss 0.4 ; sentence/s 446 ; words/s 2284 ; accuracy train : 84.54600524902344
# 243072 ; loss 0.39 ; sentence/s 442 ; words/s 2267 ; accuracy train : 84.52508544921875
# 255872 ; loss 0.38 ; sentence/s 452 ; words/s 2315 ; accuracy train : 84.53515625
# 268672 ; loss 0.4 ; sentence/s 446 ; words/s 2287 ; accuracy train : 84.51227569580078
# 281472 ; loss 0.39 ; sentence/s 448 ; words/s 2296 ; accuracy train : 84.5
# 294272 ; loss 0.4 ; sentence/s 435 ; words/s 2231 ; accuracy train : 84.4575424194336
# 307072 ; loss 0.38 ; sentence/s 446 ; words/s 2286 ; accuracy train : 84.4677734375
# 319872 ; loss 0.41 ; sentence/s 445 ; words/s 2282 ; accuracy train : 84.44312286376953
# 332672 ; loss 0.4 ; sentence/s 444 ; words/s 2273 ; accuracy train : 84.44441223144531
# 345472 ; loss 0.39 ; sentence/s 444 ; words/s 2273 ; accuracy train : 84.44010162353516
# 358272 ; loss 0.4 ; sentence/s 455 ; words/s 2331 ; accuracy train : 84.42884826660156
# 371072 ; loss 0.4 ; sentence/s 451 ; words/s 2312 ; accuracy train : 84.41783142089844
# 383872 ; loss 0.41 ; sentence/s 447 ; words/s 2289 ; accuracy train : 84.39661407470703
# 396672 ; loss 0.4 ; sentence/s 446 ; words/s 2287 ; accuracy train : 84.37676239013672
# 409472 ; loss 0.4 ; sentence/s 450 ; words/s 2307 ; accuracy train : 84.36279296875
# 422272 ; loss 0.39 ; sentence/s 451 ; words/s 2312 ; accuracy train : 84.36907958984375
# 435072 ; loss 0.41 ; sentence/s 445 ; words/s 2282 ; accuracy train : 84.34857177734375
# 447872 ; loss 0.4 ; sentence/s 445 ; words/s 2280 ; accuracy train : 84.33303833007812
# 460672 ; loss 0.41 ; sentence/s 441 ; words/s 2260 ; accuracy train : 84.30859375
# 473472 ; loss 0.41 ; sentence/s 448 ; words/s 2297 ; accuracy train : 84.28526306152344
# 486272 ; loss 0.4 ; sentence/s 441 ; words/s 2260 ; accuracy train : 84.2831039428711
# 499072 ; loss 0.4 ; sentence/s 445 ; words/s 2278 ; accuracy train : 84.27804565429688
# 511872 ; loss 0.41 ; sentence/s 447 ; words/s 2291 ; accuracy train : 84.2666015625
# 524672 ; loss 0.4 ; sentence/s 441 ; words/s 2258 ; accuracy train : 84.26390838623047
# 537472 ; loss 0.4 ; sentence/s 445 ; words/s 2278 ; accuracy train : 84.2514877319336
# results : epoch 12 ; mean accuracy train : 84.2420425415039
#
# VALIDATION : Epoch 12
# togrep : results : epoch 12 ; mean accuracy valid :              81.63990783691406

# %%
# Run best model on test set.
nli_net.load_state_dict(torch.load(os.path.join(params.outputdir, params.outputmodelname)))

print('\nTEST : Epoch {0}'.format(epoch))
evaluate(1e6, 'valid', True)
evaluate(0, 'test', True)

# Save encoder instead of full model
torch.save(nli_net.encoder.state_dict(), os.path.join(params.outputdir, params.outputmodelname + '.encoder.pkl'))
# Out:
# TEST : Epoch 15
#
# VALIDATION : Epoch 1000000.0
# finalgrep : accuracy valid : 84.24100494384766
# finalgrep : accuracy test : 84.41571807861328
