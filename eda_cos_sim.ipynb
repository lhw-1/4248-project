# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_csv("cos_sim.csv")

# %%
neutral = df[df["gold_label"] == "neutral"]
contradiction = df[df["gold_label"] == "contradiction"]
entailment = df[df["gold_label"] == "entailment"]

# %% [markdown]
# The table below shows NEUTRALs with high cosine similarity scores (close to 1)
# - Exactly the same sentences but considered neutral and not entailment. (Error?)

# %%
neutral.query("cosine_similarity > 0.999")
# Out:
#                      pairID gold_label  \
# 24720   3642220260.jpg#1r1n    neutral
# 32811   3591078425.jpg#1r1n    neutral
# 59356    512306469.jpg#4r1n    neutral
# 61374    207347050.jpg#1r1n    neutral
# 62670   4139974800.jpg#3r1n    neutral
# 101875  1472249944.jpg#1r1n    neutral
# 102588  6154676236.jpg#4r1n    neutral
# 108779  4021518793.jpg#1r1n    neutral
# 143428  3956780803.jpg#4r1n    neutral
# 151770  3989319865.jpg#0r1n    neutral
# 160129  4851882232.jpg#2r1n    neutral
# 176277  3182504961.jpg#4r1n    neutral
# 176317  4610444848.jpg#1r1n    neutral
# 179214  4151424348.jpg#0r1n    neutral
# 245337  4745081059.jpg#3r1n    neutral
# 262702  4931873269.jpg#3r1n    neutral
# 321327  2921670682.jpg#0r1n    neutral
# 325610    50594334.jpg#4r1n    neutral
# 362219  4154120779.jpg#0r1n    neutral
# 373324  3250695024.jpg#2r1n    neutral
# 381311  4377027216.jpg#2r1n    neutral
# 406849  4893958897.jpg#3r1n    neutral
# 416730  4711903148.jpg#1r1n    neutral
# ...

# %% [markdown]
# The table below shows CONTRADICTIONs with high cosine similarity scores (close to 1)
# - Exactly the same sentences but considered contradiction. (Error?)

# %%
contradiction.query("cosine_similarity > 0.999")
# Out:
#                      pairID     gold_label  \
# 59357    512306469.jpg#4r1c  contradiction
# 102586  6154676236.jpg#4r1c  contradiction
# 151769  3989319865.jpg#0r1c  contradiction
# 160130  4851882232.jpg#2r1c  contradiction
# 176276  3182504961.jpg#4r1c  contradiction
# 183705  3321209919.jpg#4r1c  contradiction
# 223343  4112704699.jpg#3r1c  contradiction
# 240531   927420680.jpg#0r1c  contradiction
# 248451  4612954712.jpg#4r1c  contradiction
# 259821    71651754.jpg#0r1c  contradiction
# 262701  4931873269.jpg#3r1c  contradiction
# 276262  2288988751.jpg#4r1c  contradiction
# 321325  2921670682.jpg#0r1c  contradiction
# 336972  4352519219.jpg#3r1c  contradiction
# 377032  8236263716.jpg#4r2c  contradiction
# 381310  4377027216.jpg#2r1c  contradiction
# 406850  4893958897.jpg#3r1c  contradiction
# 407916  1361420539.jpg#1r1c  contradiction
# 554501  3731739486.jpg#0r1c  contradiction
#
# ...

# %% [markdown]
# The table below shows ENTAILMENTs with low cosine similarity scores (cos_sim < 0)
# - Many of the explanations seems to indicate neutrality, but was still labelled entailment. (Error?)

# %%
entailment.query("cosine_similarity < 0")
# Out:
#                      pairID  gold_label  \
# 21830   3827185280.jpg#1r1e  entailment
# 22694   3033686219.jpg#3r1e  entailment
# 23515   2962977152.jpg#1r1e  entailment
# 24858   3393317338.jpg#4r1e  entailment
# 39763   2548027495.jpg#3r1e  entailment
# ...                     ...         ...
# 498800   170273913.jpg#3r1e  entailment
# 501266  3781326288.jpg#1r1e  entailment
# 534219  2915389480.jpg#4r1e  entailment
# 541543  4932403516.jpg#1r1e  entailment
# 562996  2747637478.jpg#2r1e  entailment
#
#                                                                                                Sentence1  \
# 21830             An older woman dressed in bright red traditional attire sits inside a straw structure.
# 22694                                                                      A black dog lays in the sand.
# 23515                                        Two men fighting for control of a soccer ball as fans watch
# ...

# %%
entailment.query("0 < cosine_similarity < 0.1")
# Out:
#                      pairID  gold_label  \
# 500     4476454760.jpg#0r1e  entailment
# 6168    6468440411.jpg#4r1e  entailment
# 11700   4897113571.jpg#3r1e  entailment
# 14993   2194494220.jpg#3r1e  entailment
# 24657   2217244400.jpg#0r1e  entailment
# ...                     ...         ...
# 547531  3314180199.jpg#1r1e  entailment
# 547695  5113641142.jpg#3r1e  entailment
# 550709  4450722137.jpg#4r1e  entailment
# 554180  3562001359.jpg#1r1e  entailment
# 557721  3330218126.jpg#0r1e  entailment
#
#                                                                                                         Sentence1  \
# 500                           A doctor in blue scrubs is performing an operation assisted by two men and a woman.
# 6168                                                                                  A man is smoking at sunset.
# 11700                                                             A trailer hitch is holding a large contraption.
# ...

# %%
df_no_extremes = df[(df["cosine_similarity"] < 0.99) & df["cosine_similarity"] > 0]
df_no_extremes
# Out:
#                      pairID     gold_label  \
# 0       3416050480.jpg#4r1n        neutral
# 1       3416050480.jpg#4r1c  contradiction
# 2       3416050480.jpg#4r1e     entailment
# 3       2267923837.jpg#2r1n        neutral
# 4       2267923837.jpg#2r1e     entailment
# ...                     ...            ...
# 569028  4378810163.jpg#4r1c  contradiction
# 569029  4378810163.jpg#4r1e     entailment
# 569030   152881593.jpg#1r1c  contradiction
# 569031   152881593.jpg#1r1e     entailment
# 569032   152881593.jpg#1r1n        neutral
#
#                                                                             Sentence1  \
# 0                              A person on a horse jumps over a broken down airplane.
# 1                              A person on a horse jumps over a broken down airplane.
# 2                              A person on a horse jumps over a broken down airplane.
# 3                                               Children smiling and waving at camera
# ...
