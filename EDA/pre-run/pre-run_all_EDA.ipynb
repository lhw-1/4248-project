# %% [markdown]
# This notebook features the pre-run data analysis conducted on all data (train + dev + test: 569,033 rows in total) before running of any pre-trained models, specifically in the context of cosine similarity between Premise and Hypothesis.

# %%
import pandas as pd
import seaborn as sns
pd.set_option('display.max_colwidth', None)

# %%
df_0 = pd.read_csv("./pre-run_all_data_0.csv")
df_1 = pd.read_csv("./pre-run_all_data_1.csv")
df = pd.concat([df_0, df_1])

# %%
# Peek at DataFrame to ensure data has been correctly read. 
# Columns of interests are:
# "gold_label", "Sentence1" (Premise), "Sentence2" (Hypotheses), and "cosine_similarity"
df.head()
# Out:
#                 pairID     gold_label  \
# 0  3416050480.jpg#4r1n        neutral
# 1  3416050480.jpg#4r1c  contradiction
# 2  3416050480.jpg#4r1e     entailment
# 3  2267923837.jpg#2r1n        neutral
# 4  2267923837.jpg#2r1e     entailment
#
#                                                 Sentence1  \
# 0  A person on a horse jumps over a broken down airplane.
# 1  A person on a horse jumps over a broken down airplane.
# 2  A person on a horse jumps over a broken down airplane.
# 3                   Children smiling and waving at camera
# 4                   Children smiling and waving at camera
#
#                                            Sentence2  \
# 0  A person is training his horse for a competition.
# 1      A person is at a diner, ordering an omelette.
# 2                  A person is outdoors, on a horse.
# 3                  They are smiling at their parents
# 4                         There are children present
#
#                                                                                                      Explanation_1  \
# 0                                                                 the person is not necessarily training his horse
# 1                                                One cannot be on a jumping horse cannot be a diner ordering food.
# 2                                                                               a broken down airplane is outdoors
# 3  Just because they are smiling and waving at a camera does not imply their parents or anyone is anyone behind it
# 4                                                     The children must be present to see them smiling and waving.
#
#          WorkerId  \
# 0   AF0PI3RISB5Q7
# 1  A36ZT2WFIA2HMF
# 2  A2GK75ZQTX2RDZ
# 3  A18TOIDG32QICP
# 4   AEX0YE6TUZRHT
#
#                                                 Sentence1_marked_1  \
# 0           A person on a horse jumps over a broken down airplane.
# 1   A person *on* *a* *horse* *jumps* over a broken down airplane.
# 2   A person on a horse jumps over *a* *broken* *down* *airplane.*
# 3                            Children smiling and waving at camera
# 4                    *Children* *smiling* *and* *waving* at camera
#
#                                          Sentence2_marked_1  \
# 0   A person is *training* *his* *horse* for a competition.
# 1   A person *is* *at* *a* *diner,* *ordering* an omelette.
# 2                       A person is *outdoors,* on a horse.
# 3                   They are smiling *at* *their* *parents*
# 4                              There are children *present*
#
#   Sentence1_Highlighted_1 Sentence2_Highlighted_1  cosine_similarity
# 0                      {}                   3,4,5           0.457509
# 1                 4,2,3,5               2,5,4,3,6           0.099020
# 2                8,9,10,7                       3           0.597731
# 3                      {}                   5,3,4           0.614653
# 4                 0,1,3,2                       3           0.589247

# %%
sns.set()
def label_medians(dataframe, boxplot, x, y):
    medians = round(dataframe.groupby([x])[y].median(),2)
    vertical_offset = dataframe[y].median() * 0.05
    for xtick in boxplot.get_xticks():
        boxplot.text(xtick,medians[xtick] + vertical_offset,medians[xtick], horizontalalignment='center',size='x-small',color='w',weight='semibold')
        
order=["contradiction", "entailment", "neutral"]

boxplot = sns.boxplot(data=df, x="gold_label", y="cosine_similarity", order=order)
boxplot.set_title('Cosine similarities between Premise and Hypothesis for all data\n')
label_medians(df, boxplot, "gold_label", "cosine_similarity")

# %% [markdown]
# ^^^ Running the cell above outputs a boxplot representing cosine similarities between Premise and Hypothesis for data labelled "contradiction", "entailment" and "neutral" respectively.
#
# Data observations:
# - Contradictions and entailments have the lowest and highest cosine similarities, with medians of 0.34 and 0.67 respectively, while neutral lies in between at 0.54.
# - There are many outliers which appear outside the whiskers of the boxplot, suggesting a huge variety of cosine similarities in the dataset.
#
# Data interpretations:
# - The distribution of cosine similarity medians across the labels is intuitive and makes logical sense. We would expect sentences that look wildly different from one another to be contradictions, while sentneces which are similar are more likely to entail one another.
# - Given the large number of outliers, we need to manually inspect the dataset, and exercise caution when forming conclusions due to the risk of overgeneralisation.

# %%
# Rows where Premise and Hypothesis are exactly the same, yet not an entailment.
same_not_entailment = df[(df["cosine_similarity"] > 0.9999999) & (df["gold_label"] != "entailment")]
print(f"Number of rows where Premise and Hypothesis are the same, yet not considered entailment: {len(same_not_entailment)}")
same_not_entailment.head(10)
# Out:
# Number of rows where Premise and Hypothesis are the same, yet not considered entailment: 39
#                      pairID     gold_label  \
# 24720   3642220260.jpg#1r1n        neutral
# 32811   3591078425.jpg#1r1n        neutral
# 59356    512306469.jpg#4r1n        neutral
# 59357    512306469.jpg#4r1c  contradiction
# 61374    207347050.jpg#1r1n        neutral
# 62670   4139974800.jpg#3r1n        neutral
# 101875  1472249944.jpg#1r1n        neutral
# 102586  6154676236.jpg#4r1c  contradiction
# 102588  6154676236.jpg#4r1n        neutral
# 108779  4021518793.jpg#1r1n        neutral
#
#                                                                                        Sentence1  \
# 24720                                             A black dog walks on the beach near the rocks.
# 32811             She is playing tennis with her blue tennis clothes on, it looks hot out there.
# 59356                                                A boy with blue face paint sucks his thumb.
# 59357                                                A boy with blue face paint sucks his thumb.
# 61374                                           a group of backpackers preparing for their trek.
# 62670                                                        A child is on a motorcycle smiling.
# 101875           A woman in a red jacket standing on a rock next to a woman crouching on a rock.
# 102586                                                               The image links are broken.
# 102588                                                               The image links are broken.
# 108779  A woman and a young girl walk along a wall with the numerals ninety-six adorned upon it.
#
#                                                                                        Sentence2  \
# 24720                                             A black dog walks on the beach near the rocks.
# 32811             She is playing tennis with her blue tennis clothes on, it looks hot out there.
# 59356                                                A boy with blue face paint sucks his thumb.
# 59357                                                A boy with blue face paint sucks his thumb.
# 61374                                           a group of backpackers preparing for their trek.
# 62670                                                        A child is on a motorcycle smiling.
# 101875           A woman in a red jacket standing on a rock next to a woman crouching on a rock.
# 102586                                                               The image links are broken.
# 102588                                                               The image links are broken.
# 108779  A woman and a young girl walk along a wall with the numerals ninety-six adorned upon it.
#
#                                                                                                           Explanation_1  \
# 24720                                                                                        The sentences are the same
# 32811                                             How hot the weather looks cannot be inferred from how she is dressed.
# 59356                                      They're the exact same sentence. A boy with blue face paint sucks his thumb.
# 59357                                                   Both paint sucks their thumb. The sentence does not contradict.
# 61374   A group of backpackers preparing for their trek is the same as a group of backpackers preparing for their trek.
# 62670                Because both sentences are the same, it can be inferred that the child is smiling on a motorcycle.
# 101875                                    A woman standing next to a woman does imply a woman standing next to a woman.
# 102586                                     Both sentences are the exact same. They both say the image links are broken.
# 102588                                                            this can be inferred from the image links are broken.
# 108779                                                                                 every woman is not along a wall.
#
#               WorkerId  \
# 24720   A1M4DX61EXZBMN
# 32811    AX0Q8FN7BIFGI
# 59356    AJK0123GGCII9
# 59357   A38R689MVZST8Q
# 61374    AJQGWGESKQT4Y
# 62670   A29IH4NCOUNIAM
# 101875   AJQGWGESKQT4Y
# 102586  A24UUWI8IIJKT6
# 102588   AJQGWGESKQT4Y
# 108779   AB98SGS280TY5
#
#                                                                               Sentence1_marked_1  \
# 24720                                             A black dog walks on the beach near the rocks.
# 32811             She is playing tennis with her blue tennis clothes on, it looks hot out there.
# 59356                                                A boy with blue face paint sucks his thumb.
# 59357                                            A boy with blue face *paint* *sucks* his thumb.
# 61374                                           a group of backpackers preparing for their trek.
# 62670                                                        A child is on a motorcycle smiling.
# 101875           A woman in a red jacket standing on a rock next to a woman crouching on a rock.
# 102586                                                     *The* *image* *links* *are* *broken.*
# 102588                                                               The image links are broken.
# 108779  A woman and a young girl walk along a wall with the numerals ninety-six adorned upon it.
#
#                                                                                  Sentence2_marked_1  \
# 24720                                              A black dog walks on *the* beach near the rocks.
# 32811            She is playing tennis with her blue tennis clothes on, it *looks* *hot* out there.
# 59356                                 *A* *boy* *with* *blue* *face* *paint* *sucks* *his* *thumb.*
# 59357                                               A boy with blue face *paint* *sucks* his thumb.
# 61374                              *a* *group* *of* *backpackers* *preparing* *for* *their* *trek.*
# 62670                                                         A child is on a motorcycle *smiling.*
# 101875    A *woman* in a red jacket *standing* on a rock *next* *to* a *woman* crouching on a rock.
# 102586                                                        *The* *image* *links* *are* *broken.*
# 102588                                                        *The* *image* *links* *are* *broken.*
# 108779   A *woman* and a young girl walk along a wall with the numerals ninety-six adorned upon it.
#
#        Sentence1_Highlighted_1 Sentence2_Highlighted_1  cosine_similarity
# 24720                       {}                       5                1.0
# 32811                       {}                   12,11                1.0
# 59356                       {}       0,1,2,3,4,5,6,7,8                1.0
# 59357                      5,6                     5,6                1.0
# 61374                       {}         0,1,2,3,4,5,6,7                1.0
# 62670                       {}                       6                1.0
# 101875                      {}            1,6,10,11,13                1.0
# 102586               0,1,2,3,4               0,1,2,4,3                1.0
# 102588                      {}               0,1,2,3,4                1.0
# 108779                      {}                       1                1.0

# %% [markdown]
# ^^^ Running the cell above reveals that for 39 entries, although the Premise and Hypothesis are exactly the same, the gold_label is not "entailment". These are examples of dirty data which requires cleaning.

# %%
# Rows where Premise and Hypothesis have negative cosine similarites (i.e. have some opposite meanings),
# yet is considered an entailment.
negative_entailment = df[(df["cosine_similarity"] <= 0) & (df["gold_label"] == "entailment")]
print(f"""Number of rows where Premise and Hypothesis have negative cosine_similarities, 
yet are considered entailment: {len(negative_entailment)}""")
negative_entailment
# Out:
# Number of rows where Premise and Hypothesis have negative cosine_similarities,
# yet are considered entailment: 65
#                      pairID  gold_label  \
# 21830   3827185280.jpg#1r1e  entailment
# 22694   3033686219.jpg#3r1e  entailment
# 23515   2962977152.jpg#1r1e  entailment
# 24858   3393317338.jpg#4r1e  entailment
# 39763   2548027495.jpg#3r1e  entailment
# ...                     ...         ...
# 214283   170273913.jpg#3r1e  entailment
# 216749  3781326288.jpg#1r1e  entailment
# 249702  2915389480.jpg#4r1e  entailment
# 257026  4932403516.jpg#1r1e  entailment
# 278479  2747637478.jpg#2r1e  entailment
#
#                                                                                                Sentence1  \
# 21830             An older woman dressed in bright red traditional attire sits inside a straw structure.
# 22694                                                                      A black dog lays in the sand.
# 23515                                        Two men fighting for control of a soccer ball as fans watch
# 24858                                                             One man and one female dance together.
# 39763                                                    two men waiting in line one wearing black suit.
# ...                                                                                                  ...
# 214283                                              A police officer is overlooking an outdoor festival.
# 216749                                            A bunch of people sitting outside a building at night.
# 249702                                                               Two newlyweds cut the wedding cake.
# 257026                                   A man is walking three small dogs in front of a mural painting.
# 278479  An old black man sitting on a couple of grocery crates playing the string guitar during the day.
#
#                                                      Sentence2  \
# 21830                                      the men are talking
# 22694                                      the men are talking
# 23515                                        a child was there
# 24858                                      a bird was on rocks
# 39763                                      a bird was on rocks
# ...                                                        ...
# 214283                                     the men are talking
# 216749    the dogs were fighting to get a bone from each other
# 249702                                     a bird was on rocks
# 257026                                     two girls were ther
# 278479  Someone who is visible is more than fifteen years old.
#
#                                                                                        Explanation_1  \
# 21830                                    Men are talking to a woman siting inside a straw structure.
# 22694                              The men are talking does not follow a black dog lays in the sand.
# 23515                                                A child must have been present within the fans.
# 24858   If one man and one female dance together, the bird on the rocks has nothing to do with them.
# 39763                                                     A bird is black and can also wait in line.
# ...                                                                                              ...
# 214283                                                                 a police officer can be a man
# 216749                                                                          Dogs are not people.
# 249702                                                         A wedding cake can have a bird on it.
# 257026                                                                     There is a man and girls.
# 278479                                               An old man must be more than fifteen years old.
#
#               WorkerId  \
# 21830   A1Y43ZZC64O0J9
# 22694    AJQGWGESKQT4Y
# 23515   A23D690D18OO78
# 24858    ABYS5Q4TCQZ6W
# 39763   A1LRJ6C8AI3W32
# ...                ...
# 214283   AIPIOCBP3OA9D
# 216749  A2TZAXWOB3JMNV
# 249702  A38R689MVZST8Q
# 257026  A1FS8SBR4SDWYG
# 278479             NaN
#
#                                                                                            Sentence1_marked_1  \
# 21830        An older *woman* dressed in bright red traditional attire sits *inside* *a* *straw* *structure.*
# 22694                                                               A *black* *dog* *lays* *in* *the* *sand.*
# 23515                                         Two men fighting for control of a soccer ball as *fans* *watch*
# 24858                                                      *One* *man* and *one* *female* *dance* *together.*
# 39763                                                     two men waiting in *line* one wearing *black* suit.
# ...                                                                                                       ...
# 214283                                               A *police* *officer* is overlooking an outdoor festival.
# 216749                                               A bunch of *people* sitting outside a building at night.
# 249702                                                                Two newlyweds cut the *wedding* *cake.*
# 257026                                      A *man* is walking three small dogs in front of a mural painting.
# 278479   An *old* black *man* sitting on a couple of grocery crates playing the string guitar during the day.
#
#                                                        Sentence2_marked_1  \
# 21830                                           the *men* *are* *talking*
# 22694                                         *the* *men* *are* *talking*
# 23515                                             a *child* *was* *there*
# 24858                                       *a* *bird* *was* *on* *rocks*
# 39763                                             a *bird* was on *rocks*
# ...                                                                   ...
# 214283                                              the *men* are talking
# 216749             the *dogs* were fighting to get a bone from each other
# 249702                                              a *bird* was on rocks
# 257026                                              two *girls* were ther
# 278479   Someone who is visible is *more* *than* *fifteen* *years* *old.*
#
#        Sentence1_Highlighted_1 Sentence2_Highlighted_1  cosine_similarity
# 21830            2,10,11,12,13                   3,2,1          -0.115865
# 22694              1,2,3,4,5,6                 1,0,2,3          -0.149602
# 23515                    10,11                   1,2,3          -0.042497
# 24858              0,1,3,4,5,6               0,1,2,3,4          -0.002600
# 39763                      7,4                     1,4          -0.024378
# ...                        ...                     ...                ...
# 214283                     2,1                       1          -0.014279
# 216749                       3                       1          -0.009844
# 249702                     4,5                       1          -0.037118
# 257026                       1                       1          -0.070101
# 278479                     1,3               5,6,7,8,9          -0.008149
#
# [65 rows x 11 columns]

# %% [markdown]
# Analysis incomplete. Pausing here...

# %% [markdown]
# END
