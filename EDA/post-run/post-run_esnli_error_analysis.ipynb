# %% [markdown]
# This notebook features the post-run data analysis conducted on predictions generated by the eSNLI pre-trained model, specifically in the context of cosine similarity between Premise and Hypothesis.

# %%
import pandas as pd
import numpy as np
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_colwidth', None)
from sklearn.metrics import confusion_matrix
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Liang
# [nltk_data]     Cheng\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_csv("./post-run_esnli_test_cos_sim_data.csv")

# %%
actual = df["gold_label"].tolist()
predicted = df["pred_label"].tolist()

confusion_matrix = metrics.confusion_matrix(actual, predicted)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = ["contradiction", "entailment", "neutral"])
cm_display.plot()
plt.show()

# %%
# normalize the confusion matrix
cm = confusion_matrix.astype('float') / confusion_matrix.sum(axis=1)[:, np.newaxis]

# plot the confusion matrix
fig, ax = plt.subplots()
im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)
ax.set(xticks=np.arange(cm.shape[1]),
       yticks=np.arange(cm.shape[0]),
       ylabel='True label',
       xlabel='Predicted label')

# set the threshold for text coloring
thresh = cm.max() / 2.
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, format(cm[i, j], '.2f'),
                ha="center", va="center",
                color="white" if cm[i, j] > thresh else "black")
fig.tight_layout()
plt.show()

# %% [markdown]
# From the normlised confusion matrix, we can observe the most prevalent error comes from 4 cases.
# 1. neutral→ predict contradiction
# 2. entailment → predict neural
# 3. neutral → predict entailment
# 4. contradiction → predict neutral

# %%
sns.set()
def label_medians(dataframe, boxplot, x, y):
    medians = round(dataframe.groupby([x])[y].median(),2)
    vertical_offset = dataframe[y].median() * 0.05
    for xtick in boxplot.get_xticks():
        boxplot.text(xtick,medians[xtick] + vertical_offset,medians[xtick], horizontalalignment='center',size='x-small',color='w',weight='semibold')

fig, axes = plt.subplots(1, 3, sharex=True, figsize=(15,5))
fig.suptitle('Subplots of cosine_similarity to gold_label for (1) all, (2) correctly, and (3) wrongly predicted data, respectively')

correct_df = df[df["gold_label"] == df["pred_label"]]
wrong_df = df[df["gold_label"] != df["pred_label"]]

order=["contradiction", "entailment", "neutral"]

all_boxplot = sns.boxplot(data=df, ax=axes[0], x="gold_label", y="cosine_similarity", order=order)
axes[0].set_title('All data')
label_medians(df, all_boxplot, "gold_label", "cosine_similarity")

correct_boxplot = sns.boxplot(data=correct_df, ax=axes[1], x="gold_label", y="cosine_similarity", order=order)
axes[1].set_title('Correct predictions')
label_medians(correct_df, correct_boxplot, "gold_label", "cosine_similarity")

wrong_boxplot = sns.boxplot(data=wrong_df, ax=axes[2], x="gold_label", y="cosine_similarity", order=order)
axes[2].set_title('Wrong predictions')
label_medians(wrong_df, wrong_boxplot, "gold_label", "cosine_similarity")

# plt.savefig('cos_sim_preds.png', dpi=300)

# %% [markdown]
# ^^^
# Running the cell above outputs a figure with 3 subplots. The x-axis is the "gold_label" while the y-axis is the cosine similarity between Premise and Hypothesis.
#
# Subplots definition:
# - 1st subplot encompasses all data and their predictions, whether correct or incorrect.
# - 2nd subplot encompasses data where the predictions are correct (i.e. "gold_label" == "pred_label").
# - 3rd subplot encompasses data where the predictions are wrong (i.e. "gold_label" != "pred_label")
#
# Data observation:
# - The cosine similarity between the Premise and Hypothesis of correct predictions when compared to all data seems to be about the same.
# - Cosine similarity of wrongly predicted data with 'entailment' and 'neutral' as "gold_label" seem to also be about the same as cosine similarity observed in all data.
# - However, the median cosine similarity of wrongly predicted data with 'contradiction' as "gold_label" seem to be significantly higher at 0.49 as compared to 0.33 in all data.
#
# Data interpretation:
# - This could indicate that the model has significantly more difficulty in correctly predicting contradictions where the Premise and Hypothesis have higher cosine similarity than other data.We proceed to manually inspect the data to try to figure out why contradictory sentences are much more commonly associated with an entailment prediction as opposed to a neutral prediction.

# %%
contradiction_to_entailment = df[(df["gold_label"] == "contradiction") & (df["pred_label"] == "entailment")]
contradiction_to_neutral = df[(df["gold_label"] == "contradiction") & (df["pred_label"] == "neutral")]
print(f"""Contradictions wrongly predicted as entailment: {len(contradiction_to_entailment)}
Contradictions wrongly predicted as neutral: {len(contradiction_to_neutral)}""")
# Out:
# Contradictions wrongly predicted as entailment: 137
# Contradictions wrongly predicted as neutral: 305

# %% [markdown]
# ^^^ From running the cell above, we see that the distribution of wrongly predicted contradictions are skewed towards predicting "neutral" than predicting "entailment", with a count of 305 and 137 respectively.
#
# We proceed to manually inspect the data to try to figure out why contradictory sentences are more commonly associated with a neutral prediction as opposed to an entailment prediction.

# %%
contradiction_to_neutral.sort_values(by='cosine_similarity', ascending=False).head(30)
# Out:
#          gold_label  \
# 1947  contradiction
# 3170  contradiction
# 4398  contradiction
# 8657  contradiction
# 3070  contradiction
# 9211  contradiction
# 5179  contradiction
# 1841  contradiction
# 2411  contradiction
# 8761  contradiction
# 4209  contradiction
# 7853  contradiction
# 1838  contradiction
# 5669  contradiction
# 4164  contradiction
# 8929  contradiction
# 7848  contradiction
# 4671  contradiction
# 3823  contradiction
# 4031  contradiction
# 5531  contradiction
# 994   contradiction
# 6988  contradiction
# 6957  contradiction
# 9230  contradiction
# 3970  contradiction
# 1821  contradiction
# 9783  contradiction
# 685   contradiction
# 1054  contradiction
#
#                                                                                                                                                            Premise  \
# 1947                                                                             A woman with a blue hat and blue and red jacket setting up a camera on a tripod .
# 3170                                                          A girl is swinging , rather high , on a swing with blue ropes with lots of trees in the background .
# 4398                                                                                                       A woman holds a newspaper that says `` Real change '' .
# 8657                                                                                                              Girls giving a presentation for a school class .
# 3070                                                                                                         a brown dog coming out of an orange and yellow tunnel
# 9211                                                                                                         A woman is leaning against a wall with her shoe off .
# 5179                                                              A man in a helmet and protective gear driving a go kart , numbered 65 , on a narrow paved road .
# 1841                                                                Two workers with leaf blowers blow orange leaves off patches of grass next to a wet sidewalk .
# 2411                                                                                                                               A man leads the way in a race .
# 8761                                                                                                                        A man in a black hat opens his mouth .
# 4209                                               A person is posed with one leg raised and one arm out at a competition with their teammates in the background .
# 7853                                                                                                             Painter re-creates old works of art in a museum .
# 1838                                                                                                 A woman sits in a market where she sells goods with her dog .
# 5669                                                                                                            A small group of people wait to board an MTA bus .
# 4164                                                                                                         A runner wearing purple strives for the finish line .
# 8929                                                                                                                                    A swan landing in a lake .
# 7848                                                                                               A man with thinning hair looking into glasses through glasses .
# 4671                                                                              A man in a blue jogging suit is running on the sidewalk in front of a painting .
# 3823                                             A woman in a green shirt is working within a large amount of vegetation that is at different stages of maturity .
# 4031                                                                                                              Lab tech looking through a microscope in a lab .
# 5531                                                                                                          A group of people traveling in a small wooden boat .
# 994                                                                  Three children hold a boy 's arms down while another boy in a hat shoots a water gun at him .
# 6988  A man in a suit with gold buttons and a name tag gestures with his hands as he speaks to another man in a dress shirt who is holding a beverage in a glass .
# 7853                                                                                                                        the painter ca n't paint original art work and old works of art .
# 1838                                                                                                                                                                   a woman is not a dog .
# 5669                                                                                                                                     a group ca n't be large and small at the same time .
# 4164                                                                                                                                    a runner that give up can not be at the finish line .
# 8929                                                                                                                a swan flying away from the lake can not be landing there the same time .
# 7848                                                                                                                                                the man is either full haired or has hair
# 4671                                                                                           if a man is running in front of a painting , it can not be claimed that there is no painting .
# 3823                                                                                                                                    different stages of means they are not the same age .
# 4031                                                                                                                    measuring chemicals in beakers would not be done under a microscope .
# 5531                                                                                                                                     a boat can not be large and small at the same time .
# 994                                                                                                                                                    the boys girlfriend can not be a boy .
# 6988                                                                                                                                      a man in a suit with either gold bricks or bricks .
# 6957                                                                                                              he is not be bundled up against the cold if he is wearing summer clothing .
# 9230                                                                                                                   a guy could not be attempting a layup if he is shooting a free throw .
# 3970                                                                                                   if the kids are bouncing on a trampoline , they would not be building the trampoline .
# 1821                                                                                                                 the band is not at a large venue because a local bar or club are small .
# 9783                                                                                                                            the duck ca n't be sitting on the water if he dove under it .
# 685                                                                                                                                        a boy can not be nude and wearing a bathing suit .
# 1054                                                                                                                                                      a girl is not always a schoolgirl .
#
#       cosine_similarity
# 1947           0.876593
# 3170           0.868027
# 4398           0.861503
# 8657           0.831770
# 3070           0.830999
# 9211           0.806669
# 5179           0.804753
# 1841           0.787606
# 2411           0.752420
# 8761           0.750128
# 4209           0.735019
# 7853           0.734794
# 1838           0.724913
# 5669           0.722486
# 4164           0.721262
# 8929           0.717126
# 7848           0.716212
# 4671           0.713073
# 3823           0.708628
# 4031           0.704125
# 5531           0.696857
# 994            0.693919
# 6988           0.690336
# 6957           0.689874
# 9230           0.686203
# 3970           0.684876
# 1821           0.682685
# 9783           0.681095
# 685            0.680328
# 1054           0.674190

# %% [markdown]
# ^^ From running the cell above, manual inspection of the 30 entries with highest cosine similarities where contradictory sentences are predicted as neutral, a few observations can be made:
# 1. The model misidentifies the important contradictory phrases in the Premise and Hypothesis that should be compared. Some examples are as follows:
# - Index 3170: Model does not identify the key contradictory phrases: "swing with blue ropes" and "swing with white ropes".
# - Index 4398: Model does not identify the key contradictory phrases: "holds" and "on the ground next to her".
# - Index 8657: Model does not identify the key contradictory phrases: "giving a presentation" and "watching a presentation".
#
# 2. The model correctly identifies the important contradictory phrases in the Premise and Hypothesis that should be compared, yet does not think they are contradictory, but rather, unrelated. Some examples are as follows:
# - Index 1947: Model identifies the key contradictory phrases: "woman with a blue hat" and "woman with a red hat", but mentions that the former "does not indicate" the latter.
# - Index 5531: Model identifies the key contradictory phrases: "traveling in a small wooden boat" and "waiting for a larger boat", but mentions that the former "does not mean" the latter.
# - Index 6957: Model identifies the key contradictory phrases: "skiing" and "bundled up", but mentions that the former "does not imply" the latter.
#
# 3. Some of the data are just dirty and should not have been used as input. Some examples are as follows:
# - Index 3070: A dog "coming out" of a tunnel can also be "dancing out" of the tunnel. Both statements can be true, and thus, should not have been labelled as "contradiction".
# - Index 1841: Workers who "blow orange leaves off patches of grass next to a wet sidewalk" can also "blow leaves at each other for fun", as the workers could have blown leaves from patches of grass at each other for fun. Since both statements can be true, this should not have been labelled as "contradiction".

# %% [markdown]
# ** Error cases Observed **

# %% [markdown]
# *** 1. Premise sentence length is much larger than Hypothesis ***

# %%
# create a new column to indicate if the true and predicted labels are different
df['Different'] = (df['gold_label'] != df['pred_label'])

# %%
# For example 

df[df['Different']==True].tail(2)
# Out:
#      gold_label  \
# 9812    neutral
# 9817    neutral
#
#                                                                                                                                Premise  \
# 9812  A man wearing glasses and a ragged costume is playing a Jaguar electric guitar and singing with the accompaniment of a drummer .
# 9817                              A female dancer wearing all white dancing while a photographer wearing all white takes her picture .
#
#                                          Hypothesis     pred_label  \
# 9812       Two men are playing on a street corner .  contradiction
# 9817  A girl is dancing and anothe man take a photo     entailment
#
#                          pred_expl                                    Expl_1  \
# 9812        a man is not two men .                  not all drummers are men
# 9817   a female dancer is a girl .  it not only a man who can take a photo .
#
#                                                                                            Expl_2  \
# 9812  just because two men are playing instruments it does not mean they are on a street corner .
# 9817                 the female dancer does not have to be a girl ; the dancer could be a woman .
#
#                                                                      Expl_3  \
# 9812  they might not be two men ; the drummer could be a woman or a child .
# 9817                                  the photographer might not be a man .
#
#       cosine_similarity  Different
# 9812           0.143997       True
# 9817           0.556893       True

# %%
df[df['Different']==True].iloc[35:37,0:5]
# Out:
#      gold_label  \
# 221     neutral
# 222  entailment
#
#                                                                                                                       Premise  \
# 221  An old man in a baseball hat and an old woman in a jean jacket are standing outside , but are covered mostly in shadow .
# 222  An old man in a baseball hat and an old woman in a jean jacket are standing outside , but are covered mostly in shadow .
#
#                                  Hypothesis     pred_label  \
# 221  An old woman has a light jean jacket .  contradiction
# 222        An old woman has a jean jacket .  contradiction
#
#                                                pred_expl
# 221   jean jacket is not the same as light jean jacket .
# 222             a jacket can not be both jean and jean .

# %%
# create dataframes for different and same labels
diff_labels_df = df[df['Different'] == True]
same_labels_df = df[df['Different'] == False]

# %%
diff_len_percent = ((diff_labels_df['Premise'].str.len() - diff_labels_df['Hypothesis'].str.len()) / diff_labels_df['Premise'].str.len() * 100)
same_len_percent = ((same_labels_df['Premise'].str.len() - same_labels_df['Hypothesis'].str.len()) / same_labels_df['Premise'].str.len() * 100)

# %%
# get the counts and bin edges for same_len_percent
counts_same, bin_edges_same, _ = plt.hist(same_len_percent, bins=20, alpha=0.5, label='Correct Pred')

# get the counts and bin edges for diff_len_percent
counts_diff, bin_edges_diff, _ = plt.hist(diff_len_percent, bins=20, alpha=0.5, label='Wrong Pred')
#need further normalisation to compare distributions

# %%
# normalize the counts by the total count of each distribution
counts_same_norm = counts_same / sum(counts_same)
counts_diff_norm = counts_diff / sum(counts_diff)

# plot the normalized counts
plt.plot(bin_edges_same[:-1], counts_same_norm, linestyle='-', marker='o', label='Correct Pred (Normalized)')
plt.plot(bin_edges_diff[:-1], counts_diff_norm, linestyle='-', marker='o', label='Wrong Pred (Normalized)')

# set the plot title and axis labels
plt.title('Distribution of Sentence Length Difference')
plt.xlabel('Percentage Difference')
plt.ylabel('Normalized Count')

# add a legend
plt.legend()

# show the plot
plt.show()

# %% [markdown]
# Conlusion: this error case is not valid. Generally premise is longer than hypothesis.
# Compare the distribution of sentence length difference in correct and wrong predicion:
# - Distribution is similar, just that normalised count for wrong prediction is higher when premise is much larger than hypothesis.
# - It means in the wrong prediction, a larger portion is from big length difference.

# %% [markdown]
# *** 2. In generated explanation, exactly same phrases are repeated. ***

# %%
# simple first pass check on repeated words/phrase in the generated explanation

df_exp = df[df['Different']==True]['pred_expl']

# find rows with repeated phrases
repeated_rows = []
stop_words = set(stopwords.words('english'))
for i, row in df_exp.iteritems():
    words = row.split()
    if any(words.count(w) > 1 for w in set(words) if w not in stop_words):
        repeated_rows.append(i)

# print repeated rows
df.loc[repeated_rows]
# Out:
#          gold_label  \
# 9           neutral
# 12       entailment
# 18       entailment
# 72       entailment
# 79    contradiction
# ...             ...
# 9755        neutral
# 9779        neutral
# 9783  contradiction
# 9789  contradiction
# 9795        neutral
#
#                                                                                                                   Premise  \
# 9                                                                   A statue at a museum that no seems to be looking at .
# 12                                                                          A land rover is being driven across a river .
# 18                           A blond-haired doctor and her African american assistant looking threw new medical manuals .
# 72                                                                  A man in a black shirt overlooking bike maintenance .
# 79    A man looking over a bicycle 's rear wheel in the maintenance garage with various tools visible in the background .
# ...                                                                                                                   ...
# 9755                                                                        A man and a woman embracing on the sidewalk .
# 9779   A young man in a gray shirt hovers over his beer bottle and Guinness glass pulling green things out of his beard .
# 9783                                                     A white duck is spreading its wings while sitting on the water .
# 9789                                              A group of girls jumping over another girl who is laying on the floor .
# 9795                                                            A woman in a teal apron prepares a meal at a restaurant .
#
#                                                                                                                              Hypothesis  \
# 9                                                                    The statue is offensive and people are mad that it is on display .
# 12                                                                              A Land Rover is splashing water as it crosses a river .
# 18                                                                                                        A doctor is looking at a book
# 72                                                                                                         A man watches bike repairs .
# 79                                                                                                       A man waits outside a garage .
# ...                                                                                                                                 ...
# 9755                                                                                      A woman and a man block the entire sidewalk .
# 9779  The gentleman in the t-shirt really should n't drink so much beer , as now he has little green pieces of something in his beard .
# 9783                                                The duck kept it 's wings intact when it dived under the water to catch some fish .
# 9789                                                                                                   A gorup of girl is laying down .
# 9795                                                                                              A woman prepare a lunch in restaurant
#
#          pred_label  \
# 9     contradiction
# 12          neutral
# 18    contradiction
# 72    contradiction
# 79          neutral
# ...             ...
# 9755  contradiction
# 9779  contradiction
# 9783        neutral
# 9789     entailment
# 9795     entailment
#
#                                                                                                            pred_expl  \
# 9                         the statue can not be both looking at the statue and be mad and be seen at the same time .
# 12     a land rover is being driven across a river does not imply that it is splashing water as it crosses a river .
# 18                                                                         looking and looking are different actions
# 72                                        a man can not be overlooking a bike and watching a bike at the same time .
# 79            a man looking over a bicycle 's rear wheel in the parking garage is not necessarily waiting a garage .
# ...                                                                                                              ...
# 9755                                           a man and woman can not be embracing and embracing at the same time .
# 9779                                                          the man can not be in green and green simultaneously .
# 9783       the duck may not be sitting on the water ; the duck may not be in water , and it may not be under water .
# 9789                                                girls laying on the floor is a rephrasing of girls laying down .
# 9795                                                            prepares a meal is a rephrasing of prepares a meal .
#
#                                                                                                                                                                                                                                                                                            Expl_1  \
# 9                                                                                                                                                                                                                                        not all statues are ignored because they are offensive .
# 12                                                                                                                                                                                                          a land rover being driven across a river implies that water will be splashing as it .
# 18                                                                                                                                                                                                                                                       a doctor is looking at the new medical .
# 72                                                                                                                                                                                                                                      bike repairs and bike maintenance are nearly synonymous .
# 79                                                                                                                                                                                                                               the man can not be both in the garage and outside simultaneously
# ...                                                                                                                                                                                                                                                                                           ...
# 9755                                                                                                                                                                                                                                                     of two people can not block the sidewalk
# 9779  not all gray shirts are t-shirts ; just because a man has green things in his beard does n't mean he drank too much beer or should n't drink a particular amount ; we do n't know whether he has even begun drinking , or whether he put the green things in his beard in the first place .
# 9783                                                                                                                                                                                                         the duck can not be sitting on the water and diving under the water simultaneously .
# 9789                                                                                                                                                                                                                                           jumping and laying down are different activities .
# 9795                                                                                                                                                                                                                                              you can not infer they are going to eat lunch .
#
#                                                                                                                                                 Expl_2  \
# 9                                                                         there is no indication that the statue is offensive or that people are mad .
# 12                                                                         splashing water is the direct result of driving a land rover over a river .
# 18                                                                                                                a medical manual is a type of book .
# 72                                                                                                          maintenance and repairs are the same thing
# 79                                                                                     one can not be in a garage and outside of it at the same time .
# ...                                                                                                                                                ...
# 9755                                                           even though they are embracing , they are n't necessarily going to block the sidewalk .
# 9779                                      just because a man is pulling green things out of his beard does n't mean he should n't drink so much beer .
# 9783  a duck can not be spreading it 's wings while it also kept it 's wings ; it also can not be sitting on the water when it dived under the water .
# 9789                                     a group of girls jumping over another , single girl laying on the floor contradicts the of girl laying down .
# 9795                                                                              just because a woman is preparing a meal does n't mean it 's lunch .
#
#                                                                                                             Expl_3  \
# 9     just because no one looks at a statue does not mean it is offensive and they are mad that it is on display .
# 12                                         if the land rover crosses a river , it is being driven across a river .
# 18         a doctor looking is description of blond-haired doctor looking threw or looking at a book ( medical ) .
# 72                                                       a man is watching the bike maintenance which is repairs .
# 79                                                   a man in the maintenance garage can not be outside a garage .
# ...                                                                                                            ...
# 9755              just because people are embracing on the sidewalk does not mean they block the entire sidewalk .
# 9779        just because a man is pulling things out of his beard does not mean he should n't drink so much beer .
# 9783                                                 the duck ca n't be sitting on the water if he dove under it .
# 9789                                                                 a group of girls can not be laying down while
# 9795                  just because a woman prepares a meal it does not mean the meal the woman prepares is lunch .
#
#       cosine_similarity  Different
# 9              0.565581       True
# 12             0.851856       True
# 18             0.576465       True
# 72             0.760787       True
# 79             0.542161       True
# ...                 ...        ...
# 9755           0.625618       True
# 9779           0.602002       True
# 9783           0.681095       True
# 9789           0.524917       True
# 9795           0.714251       True
#
# [661 rows x 10 columns]

# %% [markdown]
# For example, index 18, "looking and looking are different actions". It is repeating itself and arrives at wrong conlusion.
# From further random sampling, around 10% of the wrong predictions has this error case.

# %% [markdown]
# *** 3.  Similar phrases are generated for reasoning, but conclusion is wrong. ***

# %% [markdown]
# For example, index 72, "a man can not be overlooking a bike and watching a bike at the same time". "overlooking" and"watching" actually have similar meaning here but model produces a wrong conlusion.
# From further random sampling, around 15% of the wrong predictions has this error case.

# %% [markdown]
# END
